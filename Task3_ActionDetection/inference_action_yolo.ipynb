# %% [markdown]
# # YOLOv8 Inference Notebook
#
# ## 📌 Overview
# This notebook demonstrates how to perform inference using a trained YOLOv8 model on a video file, with GPU monitoring and performance logging.
#
# ```python
# # Import required libraries
# from ultralytics import YOLO
# import torch
# import GPUtil
# import psutil
# import time
# from datetime import timedelta
# import sys
# import os
# from glob import glob
# import shutil
#
# # Setup logging
# log_dir = "logs"
# os.makedirs(log_dir, exist_ok=True)
# log_file_path = os.path.join(log_dir, "inference_log.txt")
# sys.stdout = open(log_file_path, "w")
#
# print("🚀 Starting Model Inference...\n")

# %%
from ultralytics import YOLO
import torch
import GPUtil
import psutil
import time
from datetime import timedelta
import sys
import os
from glob import glob
import shutil

# Setup logging
log_dir = "logs"
os.makedirs(log_dir, exist_ok=True)
log_file_path = os.path.join(log_dir, "inference_log.txt")
sys.stdout = open(log_file_path, "w")

print("🚀 Starting Model Inference...\n")

# Device Info
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"✅ Using device: {device.upper()}\n")

# Get GPU usage before inference
gpus_before = GPUtil.getGPUs()
print("📊 GPU Usage Before Inference:")
for gpu in gpus_before:
    print(f"  Name: {gpu.name}, Memory Used: {gpu.memoryUsed}MB / {gpu.memoryTotal}MB")

# Start timer
start_time = time.time()

# Load trained model
model = YOLO('ActionYOLO/dribble_fall/weights/best.pt')

# Path to test video
test_video_path = '/home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi'

print(f"\n🎬 Running inference on video: {test_video_path}")

# Run prediction
results = model.predict(
    source=test_video_path,
    save=True,
    save_txt=True,
    save_conf=True,
    project='ActionYOLO',
    name='demo_inference',
    conf=0.25
)

# End timer
end_time = time.time()
elapsed = end_time - start_time
print(f"\n⏱️ Inference completed in: {str(timedelta(seconds=int(elapsed)))}")

# Get GPU usage after inference
gpus_after = GPUtil.getGPUs()
print("\n📊 GPU Usage After Inference:")
for gpu in gpus_after:
    print(f"  Name: {gpu.name}, Memory Used: {gpu.memoryUsed}MB / {gpu.memoryTotal}MB")

# System Info
print("\n🖥️ System Info:")
print(f"  CPU: {psutil.cpu_percent(interval=1)}% used")
print(f"  RAM: {psutil.virtual_memory().percent}% used")

# Save final video
inference_dir = 'ActionYOLO/demo_inference'
video_candidates = glob(os.path.join(inference_dir, '*.avi')) + glob(os.path.join(inference_dir, '*.mp4'))

if video_candidates:
    source_video = video_candidates[0]
    destination_video = 'ActionYOLO/final_demo_summary.mp4'
    shutil.copyfile(source_video, destination_video)
    print(f"\n✅ Predicted video saved for summary as: {destination_video}")
else:
    print("\n❌ No predicted video found in inference directory.")

# Restore stdout
sys.stdout.close()
sys.stdout = sys.__stdout__

print(f"\n💾 Inference log saved to: {log_file_path}")
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 44.9ms
# video 1/1 (frame 2/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 6.1ms
# video 1/1 (frame 3/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.8ms
# video 1/1 (frame 4/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# video 1/1 (frame 5/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# video 1/1 (frame 6/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# video 1/1 (frame 7/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# video 1/1 (frame 8/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# video 1/1 (frame 9/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# video 1/1 (frame 10/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.9ms
# video 1/1 (frame 11/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 6.2ms
# video 1/1 (frame 12/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.8ms
# video 1/1 (frame 13/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.6ms
# video 1/1 (frame 14/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.6ms
# video 1/1 (frame 15/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.6ms
# video 1/1 (frame 16/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.9ms
# video 1/1 (frame 17/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.5ms
# video 1/1 (frame 18/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.6ms
# video 1/1 (frame 19/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.9ms
# video 1/1 (frame 20/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.8ms
# video 1/1 (frame 21/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.8ms
# video 1/1 (frame 22/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.6ms
# video 1/1 (frame 23/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.8ms
# video 1/1 (frame 24/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.6ms
# video 1/1 (frame 25/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.6ms
# video 1/1 (frame 26/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.8ms
# video 1/1 (frame 27/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# video 1/1 (frame 28/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# video 1/1 (frame 29/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.6ms
# video 1/1 (frame 30/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# video 1/1 (frame 31/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.6ms
# video 1/1 (frame 32/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.8ms
# video 1/1 (frame 33/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# video 1/1 (frame 34/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# video 1/1 (frame 35/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.6ms
# video 1/1 (frame 36/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# video 1/1 (frame 37/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.9ms
# video 1/1 (frame 38/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# video 1/1 (frame 39/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.6ms
# video 1/1 (frame 40/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.9ms
# video 1/1 (frame 41/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# video 1/1 (frame 42/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# video 1/1 (frame 43/44) /home/user/YOLO_Assignment/Task_3/DataSet/HMDB51/hmdb51_org/fall_floor/Pirates_7_fall_floor_f_nm_np3_le_med_2.avi: 448x640 1 fall_floor, 5.7ms
# Speed: 2.7ms preprocess, 6.6ms inference, 19.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to ActionYOLO/demo_inference12
# 43 labels saved to ActionYOLO/demo_inference12/labels
#
# 💾 Inference log saved to: logs/inference_log.txt

# %% [markdown]
# ## 📂 Sample Outputs
#
# Here are the sample outputs from the inference process:
#
# ### 📁 Predicted Videos Folder
# 🔗 [Open Videos Folder](https://drive.google.com/drive/folders/1df38dCqChDM-ZdEALYAGiZhP7sXHkJDS?usp=sharing)
#
# ### 📄 Inference Log File
# 📝 [View Inference Log](https://drive.google.com/file/d/1TlrkBfI7qHacnjOgbVUWdZCh-s8C0ZSN/view?usp=sharing)
# 🔍 Contains detailed timing, hardware usage, and process information
#
# ### 📊 Inference Result Data
# 🗃️ [Download Result Data](https://drive.google.com/drive/folders/1Pz9us3Gw4dgESLv_1Fjrfpf-8ma1VHIc?usp=sharing)
# Includes:
# - Detection labels (YOLO format)
# - Confidence scores
# - Bounding box coordinates
# - Frame-by-frame analysis
