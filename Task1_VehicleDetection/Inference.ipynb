# %% [markdown]
# ## 🚗 YOLOv8 Inference & Evaluation on Parking Slot Detection
#
# This script performs inference and evaluation using a trained YOLOv8 model on a test dataset for detecting **empty** and **occupied** parking slots. Below is a breakdown of the script:
#
# ---
#
# ### 🔧 Configuration
# - **Model Path:** `/home/user/YOLO_Assignment/Task_1/Model/runs_train_val/detect/yolov8_parking/weights/best.pt`
# - **Data YAML:** `/home/user/YOLO_Assignment/Task_1/Dataset/dataset_yolo/data.yaml`
# - **Test Image Directory:** `/home/user/YOLO_Assignment/Task_1/Dataset/dataset_yolo/test/images`
# - **Results File:** `test_results_final.txt`
# - **Output Directory for Results:** `test_outputs`
# - **Device Used:** Automatically selects **GPU** (`cuda:0`) if available, else **CPU**
#
# ---
#
# ### 📦 Step-by-Step Process
#
# 1. **Load YOLOv8 Model**
#    Using the trained `best.pt` model from a previous run.
#
# 2. **Create Output Folder**
#    Ensures the test output directory exists for saving visual predictions.
#
# 3. **Inference on Test Images**
#    - Loads all `.jpg` images from the test directory
#    - Runs YOLOv8 inference with:
#      - Image size: 640
#      - Confidence threshold: 0.25
#      - Output images saved to the `test_outputs` directory
#
# 4. **Calculate FPS**
#    Measures the average inference speed over all test images.
#
# 5. **GPU Memory Used**
#    Reports how much GPU memory was used during inference (if CUDA is available).
#
# 6. **Model Info and Metrics**
#    - Calls `model.info()` to get architecture details
#    - Evaluates model on test set using `model.val()`:
#      - Computes overall precision, recall, mAP@0.5, mAP@0.5:0.95
#      - Also extracts per-class metrics for:
#        - `space-empty` (empty parking slot)
#        - `space-occupied` (occupied parking slot)
#
# 7. **Log Results to File**
#    Writes all metrics and info to `test_results_final.txt`.
#
# ---
#
# ### 📈 Output Summary
#
# The results saved to `test_results_final.txt` include:
# - Mean precision, recall, mAP scores
# - Per-class precision and recall
# - Model structure info
# - Inference speed (FPS)
# - GPU memory used
#
# ---
#
# ### ✅ Output
# Results printed to console and saved to:

# %%
from ultralytics import YOLO
import torch
import time
from glob import glob
import os

# === CONFIGURATION ===
MODEL_PATH = '/home/user/YOLO_Assignment/Task_1/Model/runs_train_val/detect/yolov8_parking/weights/best.pt'
DATA_YAML = '/home/user/YOLO_Assignment/Task_1/Dataset/dataset_yolo/data.yaml'
TEST_DIR = '/home/user/YOLO_Assignment/Task_1/Dataset/dataset_yolo/test/images'
LOG_FILE = 'test_results_final.txt'
SAVE_DIR = 'test_outputs'
DEVICE = 0 if torch.cuda.is_available() else 'cpu'

# === LOAD MODEL ===
model = YOLO(MODEL_PATH)

# === MAKE OUTPUT FOLDER ===
os.makedirs(SAVE_DIR, exist_ok=True)

# === INFERENCE ON TEST IMAGES ===
test_images = sorted(glob(f'{TEST_DIR}/*.jpg'))
start = time.time()
for img_path in test_images:
    model.predict(
        source=img_path,
        imgsz=640,
        conf=0.25,
        save=True,
        save_txt=False,
        save_crop=False,
        name=SAVE_DIR,
        device=DEVICE,
        verbose=False
    )
end = time.time()

# === FPS ===
fps = len(test_images) / (end - start)

# === GPU MEMORY ===
gpu_mem = torch.cuda.memory_allocated(DEVICE) / (1024 ** 3) if torch.cuda.is_available() else 0

# === MODEL INFO ===
model_info = model.info(verbose=True)

# === PRECISION, RECALL, mAP ===
metrics = model.val(data=DATA_YAML, device=DEVICE, imgsz=640, save=False, verbose=False)

# Overall metrics
precision = sum(metrics.box.p) / len(metrics.box.p)
recall = sum(metrics.box.r) / len(metrics.box.r)
map50 = sum(metrics.box.ap50) / len(metrics.box.ap50)
map = sum(metrics.box.ap) / len(metrics.box.ap)

# === PER-CLASS METRICS ===
class_names = metrics.names  # dictionary: {0: 'space-empty', 1: 'space-occupied'}
per_class_precision = metrics.box.p
per_class_recall = metrics.box.r

try:
    class_occupied = [k for k, v in class_names.items() if v == 'space-occupied'][0]
    class_empty = [k for k, v in class_names.items() if v == 'space-empty'][0]

    precision_occupied = per_class_precision[class_occupied].item()
    recall_occupied = per_class_recall[class_occupied].item()
    precision_empty = per_class_precision[class_empty].item()
    recall_empty = per_class_recall[class_empty].item()
except IndexError:
    precision_occupied = recall_occupied = precision_empty = recall_empty = -1.0
    print("❌ One or more class names not found in metrics.names!")

# === WRITE TO LOG FILE ===
with open(LOG_FILE, 'w') as f:
    f.write("=== YOLOv8 Test Summary ===\n")
    f.write(f"Model: {MODEL_PATH}\n")
    f.write(f"Device: {'CUDA' if torch.cuda.is_available() else 'CPU'}\n")
    f.write(f"Inference FPS: {fps:.2f}\n")
    f.write(f"GPU Memory Used: {gpu_mem:.2f} GB\n")
    f.write(f"Mean Precision: {precision:.4f}\n")
    f.write(f"Mean Recall: {recall:.4f}\n")
    f.write(f"mAP@0.5: {map50:.4f}\n")
    f.write(f"mAP@0.5:0.95: {map:.4f}\n")
    f.write("\n=== Per-Class Precision & Recall ===\n")
    f.write(f"Parked Vehicles (space-occupied) - Precision: {precision_occupied:.4f}, Recall: {recall_occupied:.4f}\n")
    f.write(f"Empty Slots (space-empty)       - Precision: {precision_empty:.4f}, Recall: {recall_empty:.4f}\n")
    f.write("\nModel Info:\n")
    f.write(str(model_info))
    f.write("\n=============================\n")

print("✅ Inference & evaluation complete. Results saved to:", LOG_FILE)
# Out:
# Results saved to runs/detect/test_outputs
# Results saved to runs/detect/test_outputs2
# Results saved to runs/detect/test_outputs3
# Results saved to runs/detect/test_outputs4
# Results saved to runs/detect/test_outputs5
# Results saved to runs/detect/test_outputs6
# Results saved to runs/detect/test_outputs7
# Results saved to runs/detect/test_outputs8
# Results saved to runs/detect/test_outputs9
# Results saved to runs/detect/test_outputs10
# Results saved to runs/detect/test_outputs11
# Results saved to runs/detect/test_outputs12
# Results saved to runs/detect/test_outputs13
# Results saved to runs/detect/test_outputs14
# Results saved to runs/detect/test_outputs15
# Results saved to runs/detect/test_outputs16
# Results saved to runs/detect/test_outputs17
# Results saved to runs/detect/test_outputs18
# Results saved to runs/detect/test_outputs19
# Results saved to runs/detect/test_outputs20
# Results saved to runs/detect/test_outputs21
# Results saved to runs/detect/test_outputs22
# Results saved to runs/detect/test_outputs23
# Results saved to runs/detect/test_outputs24
# Results saved to runs/detect/test_outputs25
# Results saved to runs/detect/test_outputs26
# Results saved to runs/detect/test_outputs27
# Results saved to runs/detect/test_outputs28
# Results saved to runs/detect/test_outputs29
# Results saved to runs/detect/test_outputs30
# Results saved to runs/detect/test_outputs31
# Results saved to runs/detect/test_outputs32
# Results saved to runs/detect/test_outputs33
# Results saved to runs/detect/test_outputs34
# Results saved to runs/detect/test_outputs35
# Results saved to runs/detect/test_outputs36
# Results saved to runs/detect/test_outputs37
# Results saved to runs/detect/test_outputs38
# Results saved to runs/detect/test_outputs39
# Results saved to runs/detect/test_outputs40
# Results saved to runs/detect/test_outputs41
# Results saved to runs/detect/test_outputs42
# Results saved to runs/detect/test_outputs43
# Results saved to runs/detect/test_outputs44
# Results saved to runs/detect/test_outputs45
# Results saved to runs/detect/test_outputs46
# Results saved to runs/detect/test_outputs47
# Results saved to runs/detect/test_outputs48
# Results saved to runs/detect/test_outputs49
# Results saved to runs/detect/test_outputs50
# Results saved to runs/detect/test_outputs51
# Results saved to runs/detect/test_outputs52
# Results saved to runs/detect/test_outputs53
# Results saved to runs/detect/test_outputs54
# Results saved to runs/detect/test_outputs55
# Results saved to runs/detect/test_outputs56
# Results saved to runs/detect/test_outputs57
# Results saved to runs/detect/test_outputs58
# Results saved to runs/detect/test_outputs59
# Results saved to runs/detect/test_outputs60
# Results saved to runs/detect/test_outputs61
# Results saved to runs/detect/test_outputs62
# Results saved to runs/detect/test_outputs63
# Results saved to runs/detect/test_outputs64
# Results saved to runs/detect/test_outputs65
# Results saved to runs/detect/test_outputs66
# Results saved to runs/detect/test_outputs67
# Results saved to runs/detect/test_outputs68
# Results saved to runs/detect/test_outputs69
# Results saved to runs/detect/test_outputs70
# Results saved to runs/detect/test_outputs71
# Results saved to runs/detect/test_outputs72
# Results saved to runs/detect/test_outputs73
# Results saved to runs/detect/test_outputs74
# Results saved to runs/detect/test_outputs75
# Results saved to runs/detect/test_outputs76
# Results saved to runs/detect/test_outputs77
# Results saved to runs/detect/test_outputs78
# Results saved to runs/detect/test_outputs79
# Results saved to runs/detect/test_outputs80
# Results saved to runs/detect/test_outputs81
# Results saved to runs/detect/test_outputs82
# Results saved to runs/detect/test_outputs83
# Results saved to runs/detect/test_outputs84
# Results saved to runs/detect/test_outputs85
# Results saved to runs/detect/test_outputs86
# Results saved to runs/detect/test_outputs87
# Results saved to runs/detect/test_outputs88
# Results saved to runs/detect/test_outputs89
# Results saved to runs/detect/test_outputs90
# Results saved to runs/detect/test_outputs91
# Results saved to runs/detect/test_outputs92
# Results saved to runs/detect/test_outputs93
# Results saved to runs/detect/test_outputs94
# Results saved to runs/detect/test_outputs95
# Results saved to runs/detect/test_outputs96
# Results saved to runs/detect/test_outputs97
# Results saved to runs/detect/test_outputs98
# Results saved to runs/detect/test_outputs99
# Results saved to runs/detect/test_outputs100
# Results saved to runs/detect/test_outputs101
# Results saved to runs/detect/test_outputs102
# Results saved to runs/detect/test_outputs103
# Results saved to runs/detect/test_outputs104
# Results saved to runs/detect/test_outputs105
# Results saved to runs/detect/test_outputs106
# Results saved to runs/detect/test_outputs107
# Results saved to runs/detect/test_outputs108
# Results saved to runs/detect/test_outputs109
# Results saved to runs/detect/test_outputs110
# Results saved to runs/detect/test_outputs111
# Results saved to runs/detect/test_outputs112
# Results saved to runs/detect/test_outputs113
# Results saved to runs/detect/test_outputs114
# Results saved to runs/detect/test_outputs115
# Results saved to runs/detect/test_outputs116
# Results saved to runs/detect/test_outputs117
# Results saved to runs/detect/test_outputs118
# Results saved to runs/detect/test_outputs119
# Results saved to runs/detect/test_outputs120
# Results saved to runs/detect/test_outputs121
# Results saved to runs/detect/test_outputs122
# Results saved to runs/detect/test_outputs123
# Results saved to runs/detect/test_outputs124
# Results saved to runs/detect/test_outputs125
# Results saved to runs/detect/test_outputs126
# Results saved to runs/detect/test_outputs127
# Results saved to runs/detect/test_outputs128
# Results saved to runs/detect/test_outputs129
# Results saved to runs/detect/test_outputs130
# Results saved to runs/detect/test_outputs131
# Results saved to runs/detect/test_outputs132
# Results saved to runs/detect/test_outputs133
# Results saved to runs/detect/test_outputs134
# Results saved to runs/detect/test_outputs135
# Results saved to runs/detect/test_outputs136
# Results saved to runs/detect/test_outputs137
# Results saved to runs/detect/test_outputs138
# Results saved to runs/detect/test_outputs139
# Results saved to runs/detect/test_outputs140
# Results saved to runs/detect/test_outputs141
# Results saved to runs/detect/test_outputs142
# Results saved to runs/detect/test_outputs143
# Results saved to runs/detect/test_outputs144
# Results saved to runs/detect/test_outputs145
# Results saved to runs/detect/test_outputs146
# Results saved to runs/detect/test_outputs147
# Results saved to runs/detect/test_outputs148
# Results saved to runs/detect/test_outputs149
# Results saved to runs/detect/test_outputs150
# Results saved to runs/detect/test_outputs151
# Results saved to runs/detect/test_outputs152
# Results saved to runs/detect/test_outputs153
# Results saved to runs/detect/test_outputs154
# Results saved to runs/detect/test_outputs155
# Results saved to runs/detect/test_outputs156
# Results saved to runs/detect/test_outputs157
# Results saved to runs/detect/test_outputs158
# Results saved to runs/detect/test_outputs159
# Results saved to runs/detect/test_outputs160
# Results saved to runs/detect/test_outputs161
# Results saved to runs/detect/test_outputs162
# Results saved to runs/detect/test_outputs163
# Results saved to runs/detect/test_outputs164
# Results saved to runs/detect/test_outputs165
# Results saved to runs/detect/test_outputs166
# Results saved to runs/detect/test_outputs167
# Results saved to runs/detect/test_outputs168
# Results saved to runs/detect/test_outputs169
# Results saved to runs/detect/test_outputs170
# Results saved to runs/detect/test_outputs171
# Results saved to runs/detect/test_outputs172
# Results saved to runs/detect/test_outputs173
# Results saved to runs/detect/test_outputs174
# Results saved to runs/detect/test_outputs175
# Results saved to runs/detect/test_outputs176
# Results saved to runs/detect/test_outputs177
# Results saved to runs/detect/test_outputs178
# Results saved to runs/detect/test_outputs179
# Results saved to runs/detect/test_outputs180
# Results saved to runs/detect/test_outputs181
# Results saved to runs/detect/test_outputs182
# Results saved to runs/detect/test_outputs183
# Results saved to runs/detect/test_outputs184
# Results saved to runs/detect/test_outputs185
# Results saved to runs/detect/test_outputs186
# Results saved to runs/detect/test_outputs187
# Results saved to runs/detect/test_outputs188
# Results saved to runs/detect/test_outputs189
# Results saved to runs/detect/test_outputs190
# Results saved to runs/detect/test_outputs191
# Results saved to runs/detect/test_outputs192
# Results saved to runs/detect/test_outputs193
# Results saved to runs/detect/test_outputs194
# Results saved to runs/detect/test_outputs195
# Results saved to runs/detect/test_outputs196
# Results saved to runs/detect/test_outputs197
# Results saved to runs/detect/test_outputs198
# Results saved to runs/detect/test_outputs199
# Results saved to runs/detect/test_outputs200
# Results saved to runs/detect/test_outputs201
# Results saved to runs/detect/test_outputs202
# Results saved to runs/detect/test_outputs203
# Results saved to runs/detect/test_outputs204
# Results saved to runs/detect/test_outputs205
# Results saved to runs/detect/test_outputs206
# Results saved to runs/detect/test_outputs207
# Results saved to runs/detect/test_outputs208
# Results saved to runs/detect/test_outputs209
# Results saved to runs/detect/test_outputs210
# Results saved to runs/detect/test_outputs211
# Results saved to runs/detect/test_outputs212
# Results saved to runs/detect/test_outputs213
# Results saved to runs/detect/test_outputs214
# Results saved to runs/detect/test_outputs215
# Results saved to runs/detect/test_outputs216
# Results saved to runs/detect/test_outputs217
# Results saved to runs/detect/test_outputs218
# Results saved to runs/detect/test_outputs219
# Results saved to runs/detect/test_outputs220
# Results saved to runs/detect/test_outputs221
# Results saved to runs/detect/test_outputs222
# Results saved to runs/detect/test_outputs223
# Results saved to runs/detect/test_outputs224
# Results saved to runs/detect/test_outputs225
# Results saved to runs/detect/test_outputs226
# Results saved to runs/detect/test_outputs227
# Results saved to runs/detect/test_outputs228
# Results saved to runs/detect/test_outputs229
# Results saved to runs/detect/test_outputs230
# Results saved to runs/detect/test_outputs231
# Results saved to runs/detect/test_outputs232
# Results saved to runs/detect/test_outputs233
# Results saved to runs/detect/test_outputs234
# Results saved to runs/detect/test_outputs235
# Results saved to runs/detect/test_outputs236
# Results saved to runs/detect/test_outputs237
# Results saved to runs/detect/test_outputs238
# Results saved to runs/detect/test_outputs239
# Results saved to runs/detect/test_outputs240
# Results saved to runs/detect/test_outputs241
# Results saved to runs/detect/test_outputs242
# Results saved to runs/detect/test_outputs243
# Results saved to runs/detect/test_outputs244
# Results saved to runs/detect/test_outputs245
# Results saved to runs/detect/test_outputs246
# Results saved to runs/detect/test_outputs247
# Results saved to runs/detect/test_outputs248
# Results saved to runs/detect/test_outputs249
# Results saved to runs/detect/test_outputs250
# Results saved to runs/detect/test_outputs251
# Results saved to runs/detect/test_outputs252
# Results saved to runs/detect/test_outputs253
# Results saved to runs/detect/test_outputs254
# Results saved to runs/detect/test_outputs255
# Results saved to runs/detect/test_outputs256
# Results saved to runs/detect/test_outputs257
# Results saved to runs/detect/test_outputs258
# Results saved to runs/detect/test_outputs259
# Results saved to runs/detect/test_outputs260
# Results saved to runs/detect/test_outputs261
# Results saved to runs/detect/test_outputs262
# Results saved to runs/detect/test_outputs263
# Results saved to runs/detect/test_outputs264
# Results saved to runs/detect/test_outputs265
# Results saved to runs/detect/test_outputs266
# Results saved to runs/detect/test_outputs267
# Results saved to runs/detect/test_outputs268
# Results saved to runs/detect/test_outputs269
# Results saved to runs/detect/test_outputs270
# Results saved to runs/detect/test_outputs271
# Results saved to runs/detect/test_outputs272
# Results saved to runs/detect/test_outputs273
# Results saved to runs/detect/test_outputs274
# Results saved to runs/detect/test_outputs275
# Results saved to runs/detect/test_outputs276
# Results saved to runs/detect/test_outputs277
# Results saved to runs/detect/test_outputs278
# Results saved to runs/detect/test_outputs279
# Results saved to runs/detect/test_outputs280
# Results saved to runs/detect/test_outputs281
# Results saved to runs/detect/test_outputs282
# Results saved to runs/detect/test_outputs283
# Results saved to runs/detect/test_outputs284
# Results saved to runs/detect/test_outputs285
# Results saved to runs/detect/test_outputs286
# Results saved to runs/detect/test_outputs287
# Results saved to runs/detect/test_outputs288
# Results saved to runs/detect/test_outputs289
# Results saved to runs/detect/test_outputs290
# Results saved to runs/detect/test_outputs291
# Results saved to runs/detect/test_outputs292
# Results saved to runs/detect/test_outputs293
# Results saved to runs/detect/test_outputs294
# Results saved to runs/detect/test_outputs295
# Results saved to runs/detect/test_outputs296
# Results saved to runs/detect/test_outputs297
# Results saved to runs/detect/test_outputs298
# Results saved to runs/detect/test_outputs299
# Results saved to runs/detect/test_outputs300
# Results saved to runs/detect/test_outputs301
# Results saved to runs/detect/test_outputs302
# Results saved to runs/detect/test_outputs303
# Results saved to runs/detect/test_outputs304
# Results saved to runs/detect/test_outputs305
# Results saved to runs/detect/test_outputs306
# Results saved to runs/detect/test_outputs307
# Results saved to runs/detect/test_outputs308
# Results saved to runs/detect/test_outputs309
# Results saved to runs/detect/test_outputs310
# Results saved to runs/detect/test_outputs311
# Results saved to runs/detect/test_outputs312
# Results saved to runs/detect/test_outputs313
# Results saved to runs/detect/test_outputs314
# Results saved to runs/detect/test_outputs315
# Results saved to runs/detect/test_outputs316
# Results saved to runs/detect/test_outputs317
# Results saved to runs/detect/test_outputs318
# Results saved to runs/detect/test_outputs319
# Results saved to runs/detect/test_outputs320
# Results saved to runs/detect/test_outputs321
# Results saved to runs/detect/test_outputs322
# Results saved to runs/detect/test_outputs323
# Results saved to runs/detect/test_outputs324
# Results saved to runs/detect/test_outputs325
# Results saved to runs/detect/test_outputs326
# Results saved to runs/detect/test_outputs327
# Results saved to runs/detect/test_outputs328
# Results saved to runs/detect/test_outputs329
# Results saved to runs/detect/test_outputs330
# Results saved to runs/detect/test_outputs331
# Results saved to runs/detect/test_outputs332
# Results saved to runs/detect/test_outputs333
# Results saved to runs/detect/test_outputs334
# Results saved to runs/detect/test_outputs335
# Results saved to runs/detect/test_outputs336
# Results saved to runs/detect/test_outputs337
# Results saved to runs/detect/test_outputs338
# Results saved to runs/detect/test_outputs339
# Results saved to runs/detect/test_outputs340
# Results saved to runs/detect/test_outputs341
# Results saved to runs/detect/test_outputs342
# Results saved to runs/detect/test_outputs343
# Results saved to runs/detect/test_outputs344
# Results saved to runs/detect/test_outputs345
# Results saved to runs/detect/test_outputs346
# Results saved to runs/detect/test_outputs347
# Results saved to runs/detect/test_outputs348
# Results saved to runs/detect/test_outputs349
# Results saved to runs/detect/test_outputs350
# Results saved to runs/detect/test_outputs351
# Results saved to runs/detect/test_outputs352
# Results saved to runs/detect/test_outputs353
# Results saved to runs/detect/test_outputs354
# Results saved to runs/detect/test_outputs355
# Results saved to runs/detect/test_outputs356
# Results saved to runs/detect/test_outputs357
# Results saved to runs/detect/test_outputs358
# Results saved to runs/detect/test_outputs359
# Results saved to runs/detect/test_outputs360
# Results saved to runs/detect/test_outputs361
# Results saved to runs/detect/test_outputs362
# Results saved to runs/detect/test_outputs363
# Results saved to runs/detect/test_outputs364
# Results saved to runs/detect/test_outputs365
# Results saved to runs/detect/test_outputs366
# Results saved to runs/detect/test_outputs367
# Results saved to runs/detect/test_outputs368
# Results saved to runs/detect/test_outputs369
# Results saved to runs/detect/test_outputs370
# Results saved to runs/detect/test_outputs371
# Results saved to runs/detect/test_outputs372
# Results saved to runs/detect/test_outputs373
# Results saved to runs/detect/test_outputs374
# Results saved to runs/detect/test_outputs375
# Results saved to runs/detect/test_outputs376
# Results saved to runs/detect/test_outputs377
# Results saved to runs/detect/test_outputs378
# Results saved to runs/detect/test_outputs379
# Results saved to runs/detect/test_outputs380
# Results saved to runs/detect/test_outputs381
# Results saved to runs/detect/test_outputs382
# Results saved to runs/detect/test_outputs383
# Results saved to runs/detect/test_outputs384
# Results saved to runs/detect/test_outputs385
# Results saved to runs/detect/test_outputs386
# Results saved to runs/detect/test_outputs387
# Results saved to runs/detect/test_outputs388
# Results saved to runs/detect/test_outputs389
# Results saved to runs/detect/test_outputs390
# Results saved to runs/detect/test_outputs391
# Results saved to runs/detect/test_outputs392
# Results saved to runs/detect/test_outputs393
# Results saved to runs/detect/test_outputs394
# Results saved to runs/detect/test_outputs395
# Results saved to runs/detect/test_outputs396
# Results saved to runs/detect/test_outputs397
# Results saved to runs/detect/test_outputs398
# Results saved to runs/detect/test_outputs399
# Results saved to runs/detect/test_outputs400
# Results saved to runs/detect/test_outputs401
# Results saved to runs/detect/test_outputs402
# Results saved to runs/detect/test_outputs403
# Results saved to runs/detect/test_outputs404
# Results saved to runs/detect/test_outputs405
# Results saved to runs/detect/test_outputs406
# Results saved to runs/detect/test_outputs407
# Results saved to runs/detect/test_outputs408
# Results saved to runs/detect/test_outputs409
# Results saved to runs/detect/test_outputs410
# Results saved to runs/detect/test_outputs411
# Results saved to runs/detect/test_outputs412
# Results saved to runs/detect/test_outputs413
# Results saved to runs/detect/test_outputs414
# Results saved to runs/detect/test_outputs415
# Results saved to runs/detect/test_outputs416
# Results saved to runs/detect/test_outputs417
# Results saved to runs/detect/test_outputs418
# Results saved to runs/detect/test_outputs419
# Results saved to runs/detect/test_outputs420
# Results saved to runs/detect/test_outputs421
# Results saved to runs/detect/test_outputs422
# Results saved to runs/detect/test_outputs423
# Results saved to runs/detect/test_outputs424
# Results saved to runs/detect/test_outputs425
# Results saved to runs/detect/test_outputs426
# Results saved to runs/detect/test_outputs427
# Results saved to runs/detect/test_outputs428
# Results saved to runs/detect/test_outputs429
# Results saved to runs/detect/test_outputs430
# Results saved to runs/detect/test_outputs431
# Results saved to runs/detect/test_outputs432
# Results saved to runs/detect/test_outputs433
# Results saved to runs/detect/test_outputs434
# Results saved to runs/detect/test_outputs435
# Results saved to runs/detect/test_outputs436
# Results saved to runs/detect/test_outputs437
# Results saved to runs/detect/test_outputs438
# Results saved to runs/detect/test_outputs439
# Results saved to runs/detect/test_outputs440
# Results saved to runs/detect/test_outputs441
# Results saved to runs/detect/test_outputs442
# Results saved to runs/detect/test_outputs443
# Results saved to runs/detect/test_outputs444
# Results saved to runs/detect/test_outputs445
# Results saved to runs/detect/test_outputs446
# Results saved to runs/detect/test_outputs447
# Results saved to runs/detect/test_outputs448
# Results saved to runs/detect/test_outputs449
# Results saved to runs/detect/test_outputs450
# Results saved to runs/detect/test_outputs451
# Results saved to runs/detect/test_outputs452
# Results saved to runs/detect/test_outputs453
# Results saved to runs/detect/test_outputs454
# Results saved to runs/detect/test_outputs455
# Results saved to runs/detect/test_outputs456
# Results saved to runs/detect/test_outputs457
# Results saved to runs/detect/test_outputs458
# Results saved to runs/detect/test_outputs459
# Results saved to runs/detect/test_outputs460
# Results saved to runs/detect/test_outputs461
# Results saved to runs/detect/test_outputs462
# Results saved to runs/detect/test_outputs463
# Results saved to runs/detect/test_outputs464
# Results saved to runs/detect/test_outputs465
# Results saved to runs/detect/test_outputs466
# Results saved to runs/detect/test_outputs467
# Results saved to runs/detect/test_outputs468
# Results saved to runs/detect/test_outputs469
# Results saved to runs/detect/test_outputs470
# Results saved to runs/detect/test_outputs471
# Results saved to runs/detect/test_outputs472
# Results saved to runs/detect/test_outputs473
# Results saved to runs/detect/test_outputs474
# Results saved to runs/detect/test_outputs475
# Results saved to runs/detect/test_outputs476
# Results saved to runs/detect/test_outputs477
# Results saved to runs/detect/test_outputs478
# Results saved to runs/detect/test_outputs479
# Results saved to runs/detect/test_outputs480
# Results saved to runs/detect/test_outputs481
# Results saved to runs/detect/test_outputs482
# Results saved to runs/detect/test_outputs483
# Results saved to runs/detect/test_outputs484
# Results saved to runs/detect/test_outputs485
# Results saved to runs/detect/test_outputs486
# Results saved to runs/detect/test_outputs487
# Results saved to runs/detect/test_outputs488
# Results saved to runs/detect/test_outputs489
# Results saved to runs/detect/test_outputs490
# Results saved to runs/detect/test_outputs491
# Results saved to runs/detect/test_outputs492
# Results saved to runs/detect/test_outputs493
# Results saved to runs/detect/test_outputs494
# Results saved to runs/detect/test_outputs495
# Results saved to runs/detect/test_outputs496
# Results saved to runs/detect/test_outputs497
# Results saved to runs/detect/test_outputs498
# Results saved to runs/detect/test_outputs499
# Results saved to runs/detect/test_outputs500
# Results saved to runs/detect/test_outputs501
# Results saved to runs/detect/test_outputs502
# Results saved to runs/detect/test_outputs503
# Results saved to runs/detect/test_outputs504
# Results saved to runs/detect/test_outputs505
# Results saved to runs/detect/test_outputs506
# Results saved to runs/detect/test_outputs507
# Results saved to runs/detect/test_outputs508
# Results saved to runs/detect/test_outputs509
# Results saved to runs/detect/test_outputs510
# Results saved to runs/detect/test_outputs511
# Results saved to runs/detect/test_outputs512
# Results saved to runs/detect/test_outputs513
# Results saved to runs/detect/test_outputs514
# Results saved to runs/detect/test_outputs515
# Results saved to runs/detect/test_outputs516
# Results saved to runs/detect/test_outputs517
# Results saved to runs/detect/test_outputs518
# Results saved to runs/detect/test_outputs519
# Results saved to runs/detect/test_outputs520
# Results saved to runs/detect/test_outputs521
# Results saved to runs/detect/test_outputs522
# Results saved to runs/detect/test_outputs523
# Results saved to runs/detect/test_outputs524
# Results saved to runs/detect/test_outputs525
# Results saved to runs/detect/test_outputs526
# Results saved to runs/detect/test_outputs527
# Results saved to runs/detect/test_outputs528
# Results saved to runs/detect/test_outputs529
# Results saved to runs/detect/test_outputs530
# Results saved to runs/detect/test_outputs531
# Results saved to runs/detect/test_outputs532
# Results saved to runs/detect/test_outputs533
# Results saved to runs/detect/test_outputs534
# Results saved to runs/detect/test_outputs535
# Results saved to runs/detect/test_outputs536
# Results saved to runs/detect/test_outputs537
# Results saved to runs/detect/test_outputs538
# Results saved to runs/detect/test_outputs539
# Results saved to runs/detect/test_outputs540
# Results saved to runs/detect/test_outputs541
# Results saved to runs/detect/test_outputs542
# Results saved to runs/detect/test_outputs543
# Results saved to runs/detect/test_outputs544
# Results saved to runs/detect/test_outputs545
# Results saved to runs/detect/test_outputs546
# Results saved to runs/detect/test_outputs547
# Results saved to runs/detect/test_outputs548
# Results saved to runs/detect/test_outputs549
# Results saved to runs/detect/test_outputs550
# Results saved to runs/detect/test_outputs551
# Results saved to runs/detect/test_outputs552
# Results saved to runs/detect/test_outputs553
# Results saved to runs/detect/test_outputs554
# Results saved to runs/detect/test_outputs555
# Results saved to runs/detect/test_outputs556
# Results saved to runs/detect/test_outputs557
# Results saved to runs/detect/test_outputs558
# Results saved to runs/detect/test_outputs559
# Results saved to runs/detect/test_outputs560
# Results saved to runs/detect/test_outputs561
# Results saved to runs/detect/test_outputs562
# Results saved to runs/detect/test_outputs563
# Results saved to runs/detect/test_outputs564
# Results saved to runs/detect/test_outputs565
# Results saved to runs/detect/test_outputs566
# Results saved to runs/detect/test_outputs567
# Results saved to runs/detect/test_outputs568
# Results saved to runs/detect/test_outputs569
# Results saved to runs/detect/test_outputs570
# Results saved to runs/detect/test_outputs571
# Results saved to runs/detect/test_outputs572
# Results saved to runs/detect/test_outputs573
# Results saved to runs/detect/test_outputs574
# Results saved to runs/detect/test_outputs575
# Results saved to runs/detect/test_outputs576
# Results saved to runs/detect/test_outputs577
# Results saved to runs/detect/test_outputs578
# Results saved to runs/detect/test_outputs579
# Results saved to runs/detect/test_outputs580
# Results saved to runs/detect/test_outputs581
# Results saved to runs/detect/test_outputs582
# Results saved to runs/detect/test_outputs583
# Results saved to runs/detect/test_outputs584
# Results saved to runs/detect/test_outputs585
# Results saved to runs/detect/test_outputs586
# Results saved to runs/detect/test_outputs587
# Results saved to runs/detect/test_outputs588
# Results saved to runs/detect/test_outputs589
# Results saved to runs/detect/test_outputs590
# Results saved to runs/detect/test_outputs591
# Results saved to runs/detect/test_outputs592
# Results saved to runs/detect/test_outputs593
# Results saved to runs/detect/test_outputs594
# Results saved to runs/detect/test_outputs595
# Results saved to runs/detect/test_outputs596
# Results saved to runs/detect/test_outputs597
# Results saved to runs/detect/test_outputs598
# Results saved to runs/detect/test_outputs599
# Results saved to runs/detect/test_outputs600
# Results saved to runs/detect/test_outputs601
# Results saved to runs/detect/test_outputs602
# Results saved to runs/detect/test_outputs603
# Results saved to runs/detect/test_outputs604
# Results saved to runs/detect/test_outputs605
# Results saved to runs/detect/test_outputs606
# Results saved to runs/detect/test_outputs607
# Results saved to runs/detect/test_outputs608
# Results saved to runs/detect/test_outputs609
# Results saved to runs/detect/test_outputs610
# Results saved to runs/detect/test_outputs611
# Results saved to runs/detect/test_outputs612
# Results saved to runs/detect/test_outputs613
# Results saved to runs/detect/test_outputs614
# Results saved to runs/detect/test_outputs615
# Results saved to runs/detect/test_outputs616
# Results saved to runs/detect/test_outputs617
# Results saved to runs/detect/test_outputs618
# Results saved to runs/detect/test_outputs619
# Results saved to runs/detect/test_outputs620
# Results saved to runs/detect/test_outputs621
# Results saved to runs/detect/test_outputs622
# Results saved to runs/detect/test_outputs623
# Results saved to runs/detect/test_outputs624
# Results saved to runs/detect/test_outputs625
# Results saved to runs/detect/test_outputs626
# Results saved to runs/detect/test_outputs627
# Results saved to runs/detect/test_outputs628
# Results saved to runs/detect/test_outputs629
# Results saved to runs/detect/test_outputs630
# Results saved to runs/detect/test_outputs631
# Results saved to runs/detect/test_outputs632
# Results saved to runs/detect/test_outputs633
# Results saved to runs/detect/test_outputs634
# Results saved to runs/detect/test_outputs635
# Results saved to runs/detect/test_outputs636
# Results saved to runs/detect/test_outputs637
# Results saved to runs/detect/test_outputs638
# Results saved to runs/detect/test_outputs639
# Results saved to runs/detect/test_outputs640
# Results saved to runs/detect/test_outputs641
# Results saved to runs/detect/test_outputs642
# Results saved to runs/detect/test_outputs643
# Results saved to runs/detect/test_outputs644
# Results saved to runs/detect/test_outputs645
# Results saved to runs/detect/test_outputs646
# Results saved to runs/detect/test_outputs647
# Results saved to runs/detect/test_outputs648
# Results saved to runs/detect/test_outputs649
# Results saved to runs/detect/test_outputs650
# Results saved to runs/detect/test_outputs651
# Results saved to runs/detect/test_outputs652
# Results saved to runs/detect/test_outputs653
# Results saved to runs/detect/test_outputs654
# Results saved to runs/detect/test_outputs655
# Results saved to runs/detect/test_outputs656
# Results saved to runs/detect/test_outputs657
# Results saved to runs/detect/test_outputs658
# Results saved to runs/detect/test_outputs659
# Results saved to runs/detect/test_outputs660
# Results saved to runs/detect/test_outputs661
# Results saved to runs/detect/test_outputs662
# Results saved to runs/detect/test_outputs663
# Results saved to runs/detect/test_outputs664
# Results saved to runs/detect/test_outputs665
# Results saved to runs/detect/test_outputs666
# Results saved to runs/detect/test_outputs667
# Results saved to runs/detect/test_outputs668
# Results saved to runs/detect/test_outputs669
# Results saved to runs/detect/test_outputs670
# Results saved to runs/detect/test_outputs671
# Results saved to runs/detect/test_outputs672
# Results saved to runs/detect/test_outputs673
# Results saved to runs/detect/test_outputs674
# Results saved to runs/detect/test_outputs675
# Results saved to runs/detect/test_outputs676
# Results saved to runs/detect/test_outputs677
# Results saved to runs/detect/test_outputs678
# Results saved to runs/detect/test_outputs679
# Results saved to runs/detect/test_outputs680
# Results saved to runs/detect/test_outputs681
# Results saved to runs/detect/test_outputs682
# Results saved to runs/detect/test_outputs683
# Results saved to runs/detect/test_outputs684
# Results saved to runs/detect/test_outputs685
# Results saved to runs/detect/test_outputs686
# Results saved to runs/detect/test_outputs687
# Results saved to runs/detect/test_outputs688
# Results saved to runs/detect/test_outputs689
# Results saved to runs/detect/test_outputs690
# Results saved to runs/detect/test_outputs691
# Results saved to runs/detect/test_outputs692
# Results saved to runs/detect/test_outputs693
# Results saved to runs/detect/test_outputs694
# Results saved to runs/detect/test_outputs695
# Results saved to runs/detect/test_outputs696
# Results saved to runs/detect/test_outputs697
# Results saved to runs/detect/test_outputs698
# Results saved to runs/detect/test_outputs699
# Results saved to runs/detect/test_outputs700
# Results saved to runs/detect/test_outputs701
# Results saved to runs/detect/test_outputs702
# Results saved to runs/detect/test_outputs703
# Results saved to runs/detect/test_outputs704
# Results saved to runs/detect/test_outputs705
# Results saved to runs/detect/test_outputs706
# Results saved to runs/detect/test_outputs707
# Results saved to runs/detect/test_outputs708
# Results saved to runs/detect/test_outputs709
# Results saved to runs/detect/test_outputs710
# Results saved to runs/detect/test_outputs711
# Results saved to runs/detect/test_outputs712
# Results saved to runs/detect/test_outputs713
# Results saved to runs/detect/test_outputs714
# Results saved to runs/detect/test_outputs715
# Results saved to runs/detect/test_outputs716
# Results saved to runs/detect/test_outputs717
# Results saved to runs/detect/test_outputs718
# Results saved to runs/detect/test_outputs719
# Results saved to runs/detect/test_outputs720
# Results saved to runs/detect/test_outputs721
# Results saved to runs/detect/test_outputs722
# Results saved to runs/detect/test_outputs723
# Results saved to runs/detect/test_outputs724
# Results saved to runs/detect/test_outputs725
# Results saved to runs/detect/test_outputs726
# Results saved to runs/detect/test_outputs727
# Results saved to runs/detect/test_outputs728
# Results saved to runs/detect/test_outputs729
# Results saved to runs/detect/test_outputs730
# Results saved to runs/detect/test_outputs731
# Results saved to runs/detect/test_outputs732
# Results saved to runs/detect/test_outputs733
# Results saved to runs/detect/test_outputs734
# Results saved to runs/detect/test_outputs735
# Results saved to runs/detect/test_outputs736
# Results saved to runs/detect/test_outputs737
# Results saved to runs/detect/test_outputs738
# Results saved to runs/detect/test_outputs739
# Results saved to runs/detect/test_outputs740
# Results saved to runs/detect/test_outputs741
# Results saved to runs/detect/test_outputs742
# Results saved to runs/detect/test_outputs743
# Results saved to runs/detect/test_outputs744
# Results saved to runs/detect/test_outputs745
# Results saved to runs/detect/test_outputs746
# Results saved to runs/detect/test_outputs747
# Results saved to runs/detect/test_outputs748
# Results saved to runs/detect/test_outputs749
# Results saved to runs/detect/test_outputs750
# Results saved to runs/detect/test_outputs751
# Results saved to runs/detect/test_outputs752
# Results saved to runs/detect/test_outputs753
# Results saved to runs/detect/test_outputs754
# Results saved to runs/detect/test_outputs755
# Results saved to runs/detect/test_outputs756
# Results saved to runs/detect/test_outputs757
# Results saved to runs/detect/test_outputs758
# Results saved to runs/detect/test_outputs759
# Results saved to runs/detect/test_outputs760
# Results saved to runs/detect/test_outputs761
# Results saved to runs/detect/test_outputs762
# Results saved to runs/detect/test_outputs763
# Results saved to runs/detect/test_outputs764
# Results saved to runs/detect/test_outputs765
# Results saved to runs/detect/test_outputs766
# Results saved to runs/detect/test_outputs767
# Results saved to runs/detect/test_outputs768
# Results saved to runs/detect/test_outputs769
# Results saved to runs/detect/test_outputs770
# Results saved to runs/detect/test_outputs771
# Results saved to runs/detect/test_outputs772
# Results saved to runs/detect/test_outputs773
# Results saved to runs/detect/test_outputs774
# Results saved to runs/detect/test_outputs775
# Results saved to runs/detect/test_outputs776
# Results saved to runs/detect/test_outputs777
# Results saved to runs/detect/test_outputs778
# Results saved to runs/detect/test_outputs779
# Results saved to runs/detect/test_outputs780
# Results saved to runs/detect/test_outputs781
# Results saved to runs/detect/test_outputs782
# Results saved to runs/detect/test_outputs783
# Results saved to runs/detect/test_outputs784
# Results saved to runs/detect/test_outputs785
# Results saved to runs/detect/test_outputs786
# Results saved to runs/detect/test_outputs787
# Results saved to runs/detect/test_outputs788
# Results saved to runs/detect/test_outputs789
# Results saved to runs/detect/test_outputs790
# Results saved to runs/detect/test_outputs791
# Results saved to runs/detect/test_outputs792
# Results saved to runs/detect/test_outputs793
# Results saved to runs/detect/test_outputs794
# Results saved to runs/detect/test_outputs795
# Results saved to runs/detect/test_outputs796
# Results saved to runs/detect/test_outputs797
# Results saved to runs/detect/test_outputs798
# Results saved to runs/detect/test_outputs799
# Results saved to runs/detect/test_outputs800
# Results saved to runs/detect/test_outputs801
# Results saved to runs/detect/test_outputs802
# Results saved to runs/detect/test_outputs803
# Results saved to runs/detect/test_outputs804
# Results saved to runs/detect/test_outputs805
# Results saved to runs/detect/test_outputs806
# Results saved to runs/detect/test_outputs807
# Results saved to runs/detect/test_outputs808
# Results saved to runs/detect/test_outputs809
# Results saved to runs/detect/test_outputs810
# Results saved to runs/detect/test_outputs811
# Results saved to runs/detect/test_outputs812
# Results saved to runs/detect/test_outputs813
# Results saved to runs/detect/test_outputs814
# Results saved to runs/detect/test_outputs815
# Results saved to runs/detect/test_outputs816
# Results saved to runs/detect/test_outputs817
# Results saved to runs/detect/test_outputs818
# Results saved to runs/detect/test_outputs819
# Results saved to runs/detect/test_outputs820
# Results saved to runs/detect/test_outputs821
# Results saved to runs/detect/test_outputs822
# Results saved to runs/detect/test_outputs823
# Results saved to runs/detect/test_outputs824
# Results saved to runs/detect/test_outputs825
# Results saved to runs/detect/test_outputs826
# Results saved to runs/detect/test_outputs827
# Results saved to runs/detect/test_outputs828
# Results saved to runs/detect/test_outputs829
# Results saved to runs/detect/test_outputs830
# Results saved to runs/detect/test_outputs831
# Results saved to runs/detect/test_outputs832
# Results saved to runs/detect/test_outputs833
# Results saved to runs/detect/test_outputs834
# Results saved to runs/detect/test_outputs835
# Results saved to runs/detect/test_outputs836
# Results saved to runs/detect/test_outputs837
# Results saved to runs/detect/test_outputs838
# Results saved to runs/detect/test_outputs839
# Results saved to runs/detect/test_outputs840
# Results saved to runs/detect/test_outputs841
# Results saved to runs/detect/test_outputs842
# Results saved to runs/detect/test_outputs843
# Results saved to runs/detect/test_outputs844
# Results saved to runs/detect/test_outputs845
# Results saved to runs/detect/test_outputs846
# Results saved to runs/detect/test_outputs847
# Results saved to runs/detect/test_outputs848
# Results saved to runs/detect/test_outputs849
# Results saved to runs/detect/test_outputs850
# Results saved to runs/detect/test_outputs851
# Results saved to runs/detect/test_outputs852
# Results saved to runs/detect/test_outputs853
# Results saved to runs/detect/test_outputs854
# Results saved to runs/detect/test_outputs855
# Results saved to runs/detect/test_outputs856
# Results saved to runs/detect/test_outputs857
# Results saved to runs/detect/test_outputs858
# Results saved to runs/detect/test_outputs859
# Results saved to runs/detect/test_outputs860
# Results saved to runs/detect/test_outputs861
# Results saved to runs/detect/test_outputs862
# Results saved to runs/detect/test_outputs863
# Results saved to runs/detect/test_outputs864
# Results saved to runs/detect/test_outputs865
# Results saved to runs/detect/test_outputs866
# Results saved to runs/detect/test_outputs867
# Results saved to runs/detect/test_outputs868
# Results saved to runs/detect/test_outputs869
# Results saved to runs/detect/test_outputs870
# Results saved to runs/detect/test_outputs871
# Results saved to runs/detect/test_outputs872
# Results saved to runs/detect/test_outputs873
# Results saved to runs/detect/test_outputs874
# Results saved to runs/detect/test_outputs875
# Results saved to runs/detect/test_outputs876
# Results saved to runs/detect/test_outputs877
# Results saved to runs/detect/test_outputs878
# Results saved to runs/detect/test_outputs879
# Results saved to runs/detect/test_outputs880
# Results saved to runs/detect/test_outputs881
# Results saved to runs/detect/test_outputs882
# Results saved to runs/detect/test_outputs883
# Results saved to runs/detect/test_outputs884
# Results saved to runs/detect/test_outputs885
# Results saved to runs/detect/test_outputs886
# Results saved to runs/detect/test_outputs887
# Results saved to runs/detect/test_outputs888
# Results saved to runs/detect/test_outputs889
# Results saved to runs/detect/test_outputs890
# Results saved to runs/detect/test_outputs891
# Results saved to runs/detect/test_outputs892
# Results saved to runs/detect/test_outputs893
# Results saved to runs/detect/test_outputs894
# Results saved to runs/detect/test_outputs895
# Results saved to runs/detect/test_outputs896
# Results saved to runs/detect/test_outputs897
# Results saved to runs/detect/test_outputs898
# Results saved to runs/detect/test_outputs899
# Results saved to runs/detect/test_outputs900
# Results saved to runs/detect/test_outputs901
# Results saved to runs/detect/test_outputs902
# Results saved to runs/detect/test_outputs903
# Results saved to runs/detect/test_outputs904
# Results saved to runs/detect/test_outputs905
# Results saved to runs/detect/test_outputs906
# Results saved to runs/detect/test_outputs907
# Results saved to runs/detect/test_outputs908
# Results saved to runs/detect/test_outputs909
# Results saved to runs/detect/test_outputs910
# Results saved to runs/detect/test_outputs911
# Results saved to runs/detect/test_outputs912
# Results saved to runs/detect/test_outputs913
# Results saved to runs/detect/test_outputs914
# Results saved to runs/detect/test_outputs915
# Results saved to runs/detect/test_outputs916
# Results saved to runs/detect/test_outputs917
# Results saved to runs/detect/test_outputs918
# Results saved to runs/detect/test_outputs919
# Results saved to runs/detect/test_outputs920
# Results saved to runs/detect/test_outputs921
# Results saved to runs/detect/test_outputs922
# Results saved to runs/detect/test_outputs923
# Results saved to runs/detect/test_outputs924
# Results saved to runs/detect/test_outputs925
# Results saved to runs/detect/test_outputs926
# Results saved to runs/detect/test_outputs927
# Results saved to runs/detect/test_outputs928
# Results saved to runs/detect/test_outputs929
# Results saved to runs/detect/test_outputs930
# Results saved to runs/detect/test_outputs931
# Results saved to runs/detect/test_outputs932
# Results saved to runs/detect/test_outputs933
# Results saved to runs/detect/test_outputs934
# Results saved to runs/detect/test_outputs935
# Results saved to runs/detect/test_outputs936
# Results saved to runs/detect/test_outputs937
# Results saved to runs/detect/test_outputs938
# Results saved to runs/detect/test_outputs939
# Results saved to runs/detect/test_outputs940
# Results saved to runs/detect/test_outputs941
# Results saved to runs/detect/test_outputs942
# Results saved to runs/detect/test_outputs943
# Results saved to runs/detect/test_outputs944
# Results saved to runs/detect/test_outputs945
# Results saved to runs/detect/test_outputs946
# Results saved to runs/detect/test_outputs947
# Results saved to runs/detect/test_outputs948
# Results saved to runs/detect/test_outputs949
# Results saved to runs/detect/test_outputs950
# Results saved to runs/detect/test_outputs951
# Results saved to runs/detect/test_outputs952
# Results saved to runs/detect/test_outputs953
# Results saved to runs/detect/test_outputs954
# Results saved to runs/detect/test_outputs955
# Results saved to runs/detect/test_outputs956
# Results saved to runs/detect/test_outputs957
# Results saved to runs/detect/test_outputs958
# Results saved to runs/detect/test_outputs959
# Results saved to runs/detect/test_outputs960
# Results saved to runs/detect/test_outputs961
# Results saved to runs/detect/test_outputs962
# Results saved to runs/detect/test_outputs963
# Results saved to runs/detect/test_outputs964
# Results saved to runs/detect/test_outputs965
# Results saved to runs/detect/test_outputs966
# Results saved to runs/detect/test_outputs967
# Results saved to runs/detect/test_outputs968
# Results saved to runs/detect/test_outputs969
# Results saved to runs/detect/test_outputs970
# Results saved to runs/detect/test_outputs971
# Results saved to runs/detect/test_outputs972
# Results saved to runs/detect/test_outputs973
# Results saved to runs/detect/test_outputs974
# Results saved to runs/detect/test_outputs975
# Results saved to runs/detect/test_outputs976
# Results saved to runs/detect/test_outputs977
# Results saved to runs/detect/test_outputs978
# Results saved to runs/detect/test_outputs979
# Results saved to runs/detect/test_outputs980
# Results saved to runs/detect/test_outputs981
# Results saved to runs/detect/test_outputs982
# Results saved to runs/detect/test_outputs983
# Results saved to runs/detect/test_outputs984
# Results saved to runs/detect/test_outputs985
# Results saved to runs/detect/test_outputs986
# Results saved to runs/detect/test_outputs987
# Results saved to runs/detect/test_outputs988
# Results saved to runs/detect/test_outputs989
# Results saved to runs/detect/test_outputs990
# Results saved to runs/detect/test_outputs991
# Results saved to runs/detect/test_outputs992
# Results saved to runs/detect/test_outputs993
# Results saved to runs/detect/test_outputs994
# Results saved to runs/detect/test_outputs995
# Results saved to runs/detect/test_outputs996
# Results saved to runs/detect/test_outputs997
# Results saved to runs/detect/test_outputs998
# Results saved to runs/detect/test_outputs999
# Results saved to runs/detect/test_outputs1000
# Results saved to runs/detect/test_outputs1001
# Results saved to runs/detect/test_outputs1002
# Results saved to runs/detect/test_outputs1003
# Results saved to runs/detect/test_outputs1004
# Results saved to runs/detect/test_outputs1005
# Results saved to runs/detect/test_outputs1006
# Results saved to runs/detect/test_outputs1007
# Results saved to runs/detect/test_outputs1008
# Results saved to runs/detect/test_outputs1009
# Results saved to runs/detect/test_outputs1010
# Results saved to runs/detect/test_outputs1011
# Results saved to runs/detect/test_outputs1012
# Results saved to runs/detect/test_outputs1013
# Results saved to runs/detect/test_outputs1014
# Results saved to runs/detect/test_outputs1015
# Results saved to runs/detect/test_outputs1016
# Results saved to runs/detect/test_outputs1017
# Results saved to runs/detect/test_outputs1018
# Results saved to runs/detect/test_outputs1019
# Results saved to runs/detect/test_outputs1020
# Results saved to runs/detect/test_outputs1021
# Results saved to runs/detect/test_outputs1022
# Results saved to runs/detect/test_outputs1023
# Results saved to runs/detect/test_outputs1024
# Results saved to runs/detect/test_outputs1025
# Results saved to runs/detect/test_outputs1026
# Results saved to runs/detect/test_outputs1027
# Results saved to runs/detect/test_outputs1028
# Results saved to runs/detect/test_outputs1029
# Results saved to runs/detect/test_outputs1030
# Results saved to runs/detect/test_outputs1031
# Results saved to runs/detect/test_outputs1032
# Results saved to runs/detect/test_outputs1033
# Results saved to runs/detect/test_outputs1034
# Results saved to runs/detect/test_outputs1035
# Results saved to runs/detect/test_outputs1036
# Results saved to runs/detect/test_outputs1037
# Results saved to runs/detect/test_outputs1038
# Results saved to runs/detect/test_outputs1039
# Results saved to runs/detect/test_outputs1040
# Results saved to runs/detect/test_outputs1041
# Results saved to runs/detect/test_outputs1042
# Results saved to runs/detect/test_outputs1043
# Results saved to runs/detect/test_outputs1044
# Results saved to runs/detect/test_outputs1045
# Results saved to runs/detect/test_outputs1046
# Results saved to runs/detect/test_outputs1047
# Results saved to runs/detect/test_outputs1048
# Results saved to runs/detect/test_outputs1049
# Results saved to runs/detect/test_outputs1050
# Results saved to runs/detect/test_outputs1051
# Results saved to runs/detect/test_outputs1052
# Results saved to runs/detect/test_outputs1053
# Results saved to runs/detect/test_outputs1054
# Results saved to runs/detect/test_outputs1055
# Results saved to runs/detect/test_outputs1056
# Results saved to runs/detect/test_outputs1057
# Results saved to runs/detect/test_outputs1058
# Results saved to runs/detect/test_outputs1059
# Results saved to runs/detect/test_outputs1060
# Results saved to runs/detect/test_outputs1061
# Results saved to runs/detect/test_outputs1062
# Results saved to runs/detect/test_outputs1063
# Results saved to runs/detect/test_outputs1064
# Results saved to runs/detect/test_outputs1065
# Results saved to runs/detect/test_outputs1066
# Results saved to runs/detect/test_outputs1067
# ...
# Results saved to runs/detect/test_outputs3324
# Results saved to runs/detect/test_outputs3325
# Results saved to runs/detect/test_outputs3326
# Results saved to runs/detect/test_outputs3327
# Results saved to runs/detect/test_outputs3328
# Results saved to runs/detect/test_outputs3329
# Results saved to runs/detect/test_outputs3330
# Results saved to runs/detect/test_outputs3331
# Results saved to runs/detect/test_outputs3332
# Results saved to runs/detect/test_outputs3333
# Results saved to runs/detect/test_outputs3334
# Results saved to runs/detect/test_outputs3335
# Results saved to runs/detect/test_outputs3336
# Results saved to runs/detect/test_outputs3337
# Results saved to runs/detect/test_outputs3338
# Results saved to runs/detect/test_outputs3339
# Results saved to runs/detect/test_outputs3340
# Results saved to runs/detect/test_outputs3341
# Results saved to runs/detect/test_outputs3342
# Results saved to runs/detect/test_outputs3343
# Results saved to runs/detect/test_outputs3344
# Results saved to runs/detect/test_outputs3345
# Results saved to runs/detect/test_outputs3346
# Results saved to runs/detect/test_outputs3347
# Results saved to runs/detect/test_outputs3348
# Results saved to runs/detect/test_outputs3349
# Results saved to runs/detect/test_outputs3350
# Results saved to runs/detect/test_outputs3351
# Results saved to runs/detect/test_outputs3352
# Results saved to runs/detect/test_outputs3353
# Results saved to runs/detect/test_outputs3354
# Results saved to runs/detect/test_outputs3355
# Results saved to runs/detect/test_outputs3356
# Results saved to runs/detect/test_outputs3357
# Results saved to runs/detect/test_outputs3358
# Results saved to runs/detect/test_outputs3359
# Results saved to runs/detect/test_outputs3360
# Results saved to runs/detect/test_outputs3361
# Results saved to runs/detect/test_outputs3362
# Results saved to runs/detect/test_outputs3363
# Results saved to runs/detect/test_outputs3364
# Results saved to runs/detect/test_outputs3365
# Results saved to runs/detect/test_outputs3366
# Results saved to runs/detect/test_outputs3367
# Results saved to runs/detect/test_outputs3368
# Results saved to runs/detect/test_outputs3369
# Results saved to runs/detect/test_outputs3370
# Results saved to runs/detect/test_outputs3371
# Results saved to runs/detect/test_outputs3372
# Results saved to runs/detect/test_outputs3373
# Results saved to runs/detect/test_outputs3374
# Results saved to runs/detect/test_outputs3375
# Results saved to runs/detect/test_outputs3376
# Results saved to runs/detect/test_outputs3377
# Results saved to runs/detect/test_outputs3378
# Results saved to runs/detect/test_outputs3379
# Results saved to runs/detect/test_outputs3380
# Results saved to runs/detect/test_outputs3381
# Results saved to runs/detect/test_outputs3382
# Results saved to runs/detect/test_outputs3383
# Results saved to runs/detect/test_outputs3384
# Results saved to runs/detect/test_outputs3385
# Results saved to runs/detect/test_outputs3386
# Results saved to runs/detect/test_outputs3387
# Results saved to runs/detect/test_outputs3388
# Results saved to runs/detect/test_outputs3389
# Results saved to runs/detect/test_outputs3390
# Results saved to runs/detect/test_outputs3391
# Results saved to runs/detect/test_outputs3392
# Results saved to runs/detect/test_outputs3393
# Results saved to runs/detect/test_outputs3394
# Results saved to runs/detect/test_outputs3395
# Results saved to runs/detect/test_outputs3396
# Results saved to runs/detect/test_outputs3397
# Results saved to runs/detect/test_outputs3398
# Results saved to runs/detect/test_outputs3399
# Results saved to runs/detect/test_outputs3400
# Results saved to runs/detect/test_outputs3401
# Results saved to runs/detect/test_outputs3402
# Results saved to runs/detect/test_outputs3403
# Results saved to runs/detect/test_outputs3404
# Results saved to runs/detect/test_outputs3405
# Results saved to runs/detect/test_outputs3406
# Results saved to runs/detect/test_outputs3407
# Results saved to runs/detect/test_outputs3408
# Results saved to runs/detect/test_outputs3409
# Results saved to runs/detect/test_outputs3410
# Results saved to runs/detect/test_outputs3411
# Results saved to runs/detect/test_outputs3412
# Results saved to runs/detect/test_outputs3413
# Results saved to runs/detect/test_outputs3414
# Results saved to runs/detect/test_outputs3415
# Results saved to runs/detect/test_outputs3416
# Results saved to runs/detect/test_outputs3417
# Results saved to runs/detect/test_outputs3418
# Results saved to runs/detect/test_outputs3419
# Results saved to runs/detect/test_outputs3420
# Results saved to runs/detect/test_outputs3421
# Results saved to runs/detect/test_outputs3422
# Results saved to runs/detect/test_outputs3423
# Results saved to runs/detect/test_outputs3424
# Results saved to runs/detect/test_outputs3425
# Results saved to runs/detect/test_outputs3426
# Results saved to runs/detect/test_outputs3427
# Results saved to runs/detect/test_outputs3428
# Results saved to runs/detect/test_outputs3429
# Results saved to runs/detect/test_outputs3430
# Results saved to runs/detect/test_outputs3431
# Results saved to runs/detect/test_outputs3432
# Results saved to runs/detect/test_outputs3433
# Results saved to runs/detect/test_outputs3434
# Results saved to runs/detect/test_outputs3435
# Results saved to runs/detect/test_outputs3436
# Results saved to runs/detect/test_outputs3437
# Results saved to runs/detect/test_outputs3438
# Results saved to runs/detect/test_outputs3439
# Results saved to runs/detect/test_outputs3440
# Results saved to runs/detect/test_outputs3441
# Results saved to runs/detect/test_outputs3442
# Results saved to runs/detect/test_outputs3443
# Results saved to runs/detect/test_outputs3444
# Results saved to runs/detect/test_outputs3445
# Results saved to runs/detect/test_outputs3446
# Results saved to runs/detect/test_outputs3447
# Results saved to runs/detect/test_outputs3448
# Results saved to runs/detect/test_outputs3449
# Results saved to runs/detect/test_outputs3450
# Results saved to runs/detect/test_outputs3451
# Results saved to runs/detect/test_outputs3452
# Results saved to runs/detect/test_outputs3453
# Results saved to runs/detect/test_outputs3454
# Results saved to runs/detect/test_outputs3455
# Results saved to runs/detect/test_outputs3456
# Results saved to runs/detect/test_outputs3457
# Results saved to runs/detect/test_outputs3458
# Results saved to runs/detect/test_outputs3459
# Results saved to runs/detect/test_outputs3460
# Results saved to runs/detect/test_outputs3461
# Results saved to runs/detect/test_outputs3462
# Results saved to runs/detect/test_outputs3463
# Results saved to runs/detect/test_outputs3464
# Results saved to runs/detect/test_outputs3465
# Results saved to runs/detect/test_outputs3466
# Results saved to runs/detect/test_outputs3467
# Results saved to runs/detect/test_outputs3468
# Results saved to runs/detect/test_outputs3469
# Results saved to runs/detect/test_outputs3470
# Results saved to runs/detect/test_outputs3471
# Results saved to runs/detect/test_outputs3472
# Results saved to runs/detect/test_outputs3473
# Results saved to runs/detect/test_outputs3474
# Results saved to runs/detect/test_outputs3475
# Results saved to runs/detect/test_outputs3476
# Results saved to runs/detect/test_outputs3477
# Results saved to runs/detect/test_outputs3478
# Results saved to runs/detect/test_outputs3479
# Results saved to runs/detect/test_outputs3480
# Results saved to runs/detect/test_outputs3481
# Results saved to runs/detect/test_outputs3482
# Results saved to runs/detect/test_outputs3483
# Results saved to runs/detect/test_outputs3484
# Results saved to runs/detect/test_outputs3485
# Results saved to runs/detect/test_outputs3486
# Results saved to runs/detect/test_outputs3487
# Results saved to runs/detect/test_outputs3488
# Results saved to runs/detect/test_outputs3489
# Results saved to runs/detect/test_outputs3490
# Results saved to runs/detect/test_outputs3491
# Results saved to runs/detect/test_outputs3492
# Results saved to runs/detect/test_outputs3493
# Results saved to runs/detect/test_outputs3494
# Results saved to runs/detect/test_outputs3495
# Results saved to runs/detect/test_outputs3496
# Results saved to runs/detect/test_outputs3497
# Results saved to runs/detect/test_outputs3498
# Results saved to runs/detect/test_outputs3499
# Results saved to runs/detect/test_outputs3500
# Results saved to runs/detect/test_outputs3501
# Results saved to runs/detect/test_outputs3502
# Results saved to runs/detect/test_outputs3503
# Results saved to runs/detect/test_outputs3504
# Results saved to runs/detect/test_outputs3505
# Results saved to runs/detect/test_outputs3506
# Results saved to runs/detect/test_outputs3507
# Results saved to runs/detect/test_outputs3508
# Results saved to runs/detect/test_outputs3509
# Results saved to runs/detect/test_outputs3510
# Results saved to runs/detect/test_outputs3511
# Results saved to runs/detect/test_outputs3512
# Results saved to runs/detect/test_outputs3513
# Results saved to runs/detect/test_outputs3514
# Results saved to runs/detect/test_outputs3515
# Results saved to runs/detect/test_outputs3516
# Results saved to runs/detect/test_outputs3517
# Results saved to runs/detect/test_outputs3518
# Results saved to runs/detect/test_outputs3519
# Results saved to runs/detect/test_outputs3520
# Results saved to runs/detect/test_outputs3521
# Results saved to runs/detect/test_outputs3522
# Results saved to runs/detect/test_outputs3523
# Results saved to runs/detect/test_outputs3524
# Results saved to runs/detect/test_outputs3525
# Results saved to runs/detect/test_outputs3526
# Results saved to runs/detect/test_outputs3527
# Results saved to runs/detect/test_outputs3528
# Results saved to runs/detect/test_outputs3529
# Results saved to runs/detect/test_outputs3530
# Results saved to runs/detect/test_outputs3531
# Results saved to runs/detect/test_outputs3532
# Results saved to runs/detect/test_outputs3533
# Results saved to runs/detect/test_outputs3534
# Results saved to runs/detect/test_outputs3535
# Results saved to runs/detect/test_outputs3536
# Results saved to runs/detect/test_outputs3537
# Results saved to runs/detect/test_outputs3538
# Results saved to runs/detect/test_outputs3539
# Results saved to runs/detect/test_outputs3540
# Results saved to runs/detect/test_outputs3541
# Results saved to runs/detect/test_outputs3542
# Results saved to runs/detect/test_outputs3543
# Results saved to runs/detect/test_outputs3544
# Results saved to runs/detect/test_outputs3545
# Results saved to runs/detect/test_outputs3546
# Results saved to runs/detect/test_outputs3547
# Results saved to runs/detect/test_outputs3548
# Results saved to runs/detect/test_outputs3549
# Results saved to runs/detect/test_outputs3550
# Results saved to runs/detect/test_outputs3551
# Results saved to runs/detect/test_outputs3552
# Results saved to runs/detect/test_outputs3553
# Results saved to runs/detect/test_outputs3554
# Results saved to runs/detect/test_outputs3555
# Results saved to runs/detect/test_outputs3556
# Results saved to runs/detect/test_outputs3557
# Results saved to runs/detect/test_outputs3558
# Results saved to runs/detect/test_outputs3559
# Results saved to runs/detect/test_outputs3560
# Results saved to runs/detect/test_outputs3561
# Results saved to runs/detect/test_outputs3562
# Results saved to runs/detect/test_outputs3563
# Results saved to runs/detect/test_outputs3564
# Results saved to runs/detect/test_outputs3565
# Results saved to runs/detect/test_outputs3566
# Results saved to runs/detect/test_outputs3567
# Results saved to runs/detect/test_outputs3568
# Results saved to runs/detect/test_outputs3569
# Results saved to runs/detect/test_outputs3570
# Results saved to runs/detect/test_outputs3571
# Results saved to runs/detect/test_outputs3572
# Results saved to runs/detect/test_outputs3573
# Results saved to runs/detect/test_outputs3574
# Results saved to runs/detect/test_outputs3575
# Results saved to runs/detect/test_outputs3576
# Results saved to runs/detect/test_outputs3577
# Results saved to runs/detect/test_outputs3578
# Results saved to runs/detect/test_outputs3579
# Results saved to runs/detect/test_outputs3580
# Results saved to runs/detect/test_outputs3581
# Results saved to runs/detect/test_outputs3582
# Results saved to runs/detect/test_outputs3583
# Results saved to runs/detect/test_outputs3584
# Results saved to runs/detect/test_outputs3585
# Results saved to runs/detect/test_outputs3586
# Results saved to runs/detect/test_outputs3587
# Results saved to runs/detect/test_outputs3588
# Results saved to runs/detect/test_outputs3589
# Results saved to runs/detect/test_outputs3590
# Results saved to runs/detect/test_outputs3591
# Results saved to runs/detect/test_outputs3592
# Results saved to runs/detect/test_outputs3593
# Results saved to runs/detect/test_outputs3594
# Results saved to runs/detect/test_outputs3595
# Results saved to runs/detect/test_outputs3596
# Results saved to runs/detect/test_outputs3597
# Results saved to runs/detect/test_outputs3598
# Results saved to runs/detect/test_outputs3599
# Results saved to runs/detect/test_outputs3600
# Results saved to runs/detect/test_outputs3601
# Results saved to runs/detect/test_outputs3602
# Results saved to runs/detect/test_outputs3603
# Results saved to runs/detect/test_outputs3604
# Results saved to runs/detect/test_outputs3605
# Results saved to runs/detect/test_outputs3606
# Results saved to runs/detect/test_outputs3607
# Results saved to runs/detect/test_outputs3608
# Results saved to runs/detect/test_outputs3609
# Results saved to runs/detect/test_outputs3610
# Results saved to runs/detect/test_outputs3611
# Results saved to runs/detect/test_outputs3612
# Results saved to runs/detect/test_outputs3613
# Results saved to runs/detect/test_outputs3614
# Results saved to runs/detect/test_outputs3615
# Results saved to runs/detect/test_outputs3616
# Results saved to runs/detect/test_outputs3617
# Results saved to runs/detect/test_outputs3618
# Results saved to runs/detect/test_outputs3619
# Results saved to runs/detect/test_outputs3620
# Results saved to runs/detect/test_outputs3621
# Results saved to runs/detect/test_outputs3622
# Results saved to runs/detect/test_outputs3623
# Results saved to runs/detect/test_outputs3624
# Results saved to runs/detect/test_outputs3625
# Results saved to runs/detect/test_outputs3626
# Results saved to runs/detect/test_outputs3627
# Results saved to runs/detect/test_outputs3628
# Results saved to runs/detect/test_outputs3629
# Results saved to runs/detect/test_outputs3630
# Results saved to runs/detect/test_outputs3631
# Results saved to runs/detect/test_outputs3632
# Results saved to runs/detect/test_outputs3633
# Results saved to runs/detect/test_outputs3634
# Results saved to runs/detect/test_outputs3635
# Results saved to runs/detect/test_outputs3636
# Results saved to runs/detect/test_outputs3637
# Results saved to runs/detect/test_outputs3638
# Results saved to runs/detect/test_outputs3639
# Results saved to runs/detect/test_outputs3640
# Results saved to runs/detect/test_outputs3641
# Results saved to runs/detect/test_outputs3642
# Results saved to runs/detect/test_outputs3643
# Results saved to runs/detect/test_outputs3644
# Results saved to runs/detect/test_outputs3645
# Results saved to runs/detect/test_outputs3646
# Results saved to runs/detect/test_outputs3647
# Results saved to runs/detect/test_outputs3648
# Model summary (fused): 72 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# Ultralytics 8.3.151 🚀 Python-3.11.9 torch-2.5.1 CUDA:0 (Quadro RTX 5000, 16115MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3233.8±929.7 MB/s, size: 267.4 KB)
# val: Scanning /home/user/YOLO_Assignment/Task_1/Dataset/dataset_yolo/valid/labels.cache... 7272 images, 0 backgrounds, 0 corrupt: 100%|██████████| 7272/7272
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   1%|          | 3/455 [00:10<28:58,  3.85s/it]
# WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 455/455 [01:48<00:00,  4.18it/s]
#                    all       7272     429948      0.999      0.996      0.995      0.982
# Speed: 0.1ms preprocess, 3.4ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to runs/detect/val
# ✅ Inference & evaluation complete. Results saved to: test_results_final.txt

# %% [markdown]
# # YOLOv8 Parking Space Detection - Test Results
#
# ## Model Performance Summary
#
# - **Model Path**: `/home/user/YOLO_Assignment/Task_1/Model/runs_train_val/detect/yolov8_parking/weights/best.pt`
# - **Device**: CUDA
# - **Inference Speed**: 17.02 FPS
# - **GPU Memory Usage**: 0.02 GB
# - **Mean Precision**: 0.9985
# - **Mean Recall**: 0.9956
# - **mAP@0.5**: 0.9946
# - **mAP@0.5:0.95**: 0.9823
#
# ## Detailed Metrics
#
# | Metric          | Value   |
# |-----------------|---------|
# | Images Processed | 7,272   |
# | Instances       | 429,948 |
# | Box Precision   | 0.999   |
# | Box Recall      | 0.996   |
# | mAP50           | 0.995   |
# | mAP50-95        | 0.982   |
#
# ## Speed Analysis
#
# | Phase          | Time per Image |
# |----------------|----------------|
# | Preprocess     | 0.1 ms         |
# | Inference      | 3.4 ms         |
# | Loss           | 0.0 ms         |
# | Postprocess    | 1.5 ms         |
#
# ## Per-Class Performance
#
# | Class                     | Precision | Recall  |
# |---------------------------|-----------|---------|
# | Parked Vehicles (occupied)| 0.9984    | 0.9945  |
# | Empty Slots               | 0.9986    | 0.9967  |
#
# ## Model Information
#
# - Architecture: (72, 3006038, 0, 8.086272)
#
# > Results saved to: `runs/detect/val`

# %% [markdown]
# ## YOLOv8 Test Set Detection Outputs
#
# ## Output Visualizations
#
# The detection outputs from the test set are available for review:
#
# 📁 [View Test Set Detection Outputs on Google Drive](https://drive.google.com/drive/folders/1SE_JZDAUbTKTk64N4kbA6v3WweebN5Bo?usp=sharing)

# %% [markdown]
# ## 🎥 YOLOv8 Inference on Video/Image for Parking Slot Detection
#
# This section performs inference using a trained YOLOv8 model on either a **video file** (e.g., `.mp4`) or a **single image**. The model detects and classifies parking slots into two categories:
# - `space-empty` (class ID 0)
# - `space-occupied` (class ID 1)
#
# ---
#
# ### ⚙️ Configuration
#
# - **Model Path:**
#   `/home/user/YOLO_Assignment/Task_1/Model/runs/detect/yolov8_parking/weights/best.pt`
#
# - **Input Video/Image:**
#   `/home/user/YOLO_Assignment/Task_1/Dataset/sample_parking.mp4`
#
# - **Device Used:**
#   Automatically selects `CUDA` if available, otherwise falls back to `CPU`.
#
# - **Output Files:**
#   - Annotated frames and summary video saved to: `inference_outputs/`
#   - Inference log: `inference_outputs/inference_log.txt`
#   - Frame-wise slot counts: `inference_outputs/frame_counts.txt`
#
# ---
#
# ### 🚀 Inference Flow
#
# 1. **Model Loading:** YOLOv8 model is loaded using Ultralytics API.
# 2. **Input Handling:**
#    - If the input is a **video**, it reads each frame and applies detection.
#    - If the input is a **single image**, it processes it directly.
# 3. **Detection & Annotation:**
#    - The model predicts bounding boxes per frame.
#    - Counts `space-empty` and `space-occupied` slots.
#    - Adds the counts as overlay text on the frame.
# 4. **Saving Outputs:**
#    - Annotated frames saved as `.jpg`.
#    - Frame-wise slot counts logged.
#    - A summary video with annotations is generated (if input is a video).
# 5. **Performance Metrics:**
#    - Calculates average FPS and GPU memory used.
#
# ---

# %%
from ultralytics import YOLO
import torch
import time
import cv2
import os

# === CONFIGURATION ===
MODEL_PATH = '/home/user/YOLO_Assignment/Task_1/Model/runs/detect/yolov8_parking/weights/best.pt'
DATA_YAML = '/home/user/YOLO_Assignment/Task_1/Dataset/dataset_yolo/data.yaml'
INPUT_PATH ='/home/user/YOLO_Assignment/Task_1/Dataset/sample_parking.mp4'
OUTPUT_DIR = 'inference_outputs'
LOG_FILE = os.path.join(OUTPUT_DIR, 'inference_log.txt')
FRAME_COUNTS_FILE = os.path.join(OUTPUT_DIR, 'frame_counts.txt')
SUMMARY_VIDEO_PATH = os.path.join(OUTPUT_DIR, 'summary_output.mp4')
DEVICE = 0 if torch.cuda.is_available() else 'cpu'

# === CREATE OUTPUT DIR ===
os.makedirs(OUTPUT_DIR, exist_ok=True)

# === LOAD MODEL ===
model = YOLO(MODEL_PATH)

# === HELPER: PROCESS FRAME ===
def process_frame(frame, frame_id=None, writer=None, count_writer=None):
    results = model.predict(source=frame, device=DEVICE, conf=0.25, save=False, verbose=False)[0]

    total_empty = 0
    total_occupied = 0

    for box in results.boxes:
        cls = int(box.cls[0])
        if cls == 0:
            total_empty += 1
        elif cls == 1:
            total_occupied += 1

    annotated = results.plot()
    overlay_text = f"Empty: {total_empty} | Occupied: {total_occupied}"
    cv2.putText(annotated, overlay_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)

    if frame_id is not None:
        img_name = f"frame_{frame_id:04d}.jpg"
        cv2.imwrite(os.path.join(OUTPUT_DIR, img_name), annotated)
        if count_writer:
            count_writer.write(f"{img_name} --> Empty: {total_empty}, Occupied: {total_occupied}\n")

    if writer:
        writer.write(annotated)

    return total_empty, total_occupied

# === INFERENCE ===
is_video = INPUT_PATH.lower().endswith(('.mp4', '.avi', '.mov'))
start = time.time()

avg_empty = avg_occupied = 0
frame_count = 0

with open(FRAME_COUNTS_FILE, 'w') as count_writer:
    if is_video:
        cap = cv2.VideoCapture(INPUT_PATH)
        frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fps_input = cap.get(cv2.CAP_PROP_FPS)

        writer = cv2.VideoWriter(SUMMARY_VIDEO_PATH, cv2.VideoWriter_fourcc(*'mp4v'), fps_input,
                                 (frame_width, frame_height))

        total_empty_sum = 0
        total_occupied_sum = 0

        while True:
            ret, frame = cap.read()
            if not ret:
                break
            empty, occupied = process_frame(frame, frame_id=frame_count, writer=writer, count_writer=count_writer)
            total_empty_sum += empty
            total_occupied_sum += occupied
            frame_count += 1

        cap.release()
        writer.release()

        avg_empty = total_empty_sum // frame_count
        avg_occupied = total_occupied_sum // frame_count

    else:
        frame = cv2.imread(INPUT_PATH)
        frame_count = 1
        avg_empty, avg_occupied = process_frame(frame, frame_id=0, count_writer=count_writer)
        cv2.imwrite(os.path.join(OUTPUT_DIR, 'output.jpg'), frame)

end = time.time()

# === METRICS ===
fps = frame_count / (end - start)
gpu_mem = torch.cuda.memory_allocated(DEVICE) / (1024 ** 3) if torch.cuda.is_available() else 0

# === LOGGING ===
with open(LOG_FILE, 'w') as f:
    f.write("=== Inference Results ===\n")
    f.write(f"Model: {MODEL_PATH}\n")
    f.write(f"Device: {'CUDA' if torch.cuda.is_available() else 'CPU'}\n")
    f.write(f"Input: {INPUT_PATH}\n")
    f.write(f"FPS: {fps:.2f}\n")
    f.write(f"GPU Memory Used: {gpu_mem:.2f} GB\n")
    f.write(f"Total Occupied Slots: {avg_occupied}\n")
    f.write(f"Total Empty Slots: {avg_empty}\n")
    f.write("=========================\n")

# === COMPLETION MESSAGE ===
print(" Inference complete.")
print(f" Log saved at: {LOG_FILE}")
print(f" Frame-wise counts saved at: {FRAME_COUNTS_FILE}")
print(f" Output images saved at: {OUTPUT_DIR}")
if is_video:
    print(f" Summary video saved at: {SUMMARY_VIDEO_PATH}")
# Out:
#  Inference complete.
#  Log saved at: inference_outputs/inference_log.txt
#  Frame-wise counts saved at: inference_outputs/frame_counts.txt
#  Output images saved at: inference_outputs
#  Summary video saved at: inference_outputs/summary_output.mp4

# %% [markdown]
# ## 📂 Downloadable Resources for Inference Demo
#
# Below are links to **sample inputs**, the **output video after detection**, and **detailed inference results**, including per-frame bounding box images and logs.
#
# ---
#
# ### 🔗 Sample Input Video
# 🎥 A test video demonstrating parking lot occupancy status.
#
# 👉 [Click to Download Sample Input Video](https://drive.google.com/drive/folders/1SSkWE9dVIxG6V5gL_z4RCzgiRNpLKZWH?usp=sharing)
#
# ---
#
# ### 🔗 Output Summary Video (With Detections)
# 📽️ YOLOv8-inferred video showing bounding boxes and class labels for each frame.
#
# 👉 [Click to Download Output Result Video](https://drive.google.com/drive/folders/1BgvYgd7-cGmmOBeb2eqhkq-3wTkT6URn?usp=sharing)
#
# ---
#
# ### 🔗 Annotated Frames, Logs & Count Files
# 📁 This archive contains:
# - Annotated frames with bounding boxes
# - `inference_log.txt` summarizing FPS, GPU usage, slot counts
# - `frame_counts.txt` listing per-frame empty/occupied slot data
#
# 👉 [Click to Download Output Frames and Logs](https://drive.google.com/drive/folders/10KqXTMcfNwmrX5cxEsTpXIl2gxlMuG2w?usp=sharing)
#
# ---
#
# ### 📌 Notes
# - Each output frame includes overlay text like `Empty: 23 | Occupied: 17`.
# - Suitable for visual validation of detection quality and performance.
#
# Make sure you're logged in to your Google account if access is restricted.

# %% [markdown]
# ## 📊 YOLOv8 Parking Detection: Inference Results on Sample Video
#
# This section presents the output of a YOLOv8 model used to detect **occupied** and **empty** parking slots in a sample video.
#
# ---
#
# ### 🧠 Model & Environment Configuration
#
# | Item              | Value                                                                 |
# |-------------------|-----------------------------------------------------------------------|
# | **Model Path**     | `/home/user/YOLO_Assignment/Task_1/Model/runs/detect/yolov8_parking/weights/best.pt` |
# | **Device Used**    | CUDA (GPU)                                                            |
# | **Input Source**   | `/home/user/YOLO_Assignment/Task_1/Dataset/sample_parking.mp4`       |
# | **Frames Processed** | 132+ frames                                                        |
# | **FPS**            | 13.06                                                                 |
# | **GPU Memory Used**| 0.02 GB                                                               |
# | **Avg Occupied Slots** | 4                                                                |
# | **Avg Empty Slots**    | 0                                                                |
#
# ---

# %% [markdown]
# # Top 10 Frames with Highest Occupied Slots
#
# | Frame Name     | Empty | Occupied |
# |----------------|--------|-----------|
# | frame_0131.jpg |   1    |    17     |
# | frame_0152.jpg |   0    |    14     |
# | frame_0151.jpg |   1    |    13     |
# | frame_0136.jpg |   1    |    13     |
# | frame_0159.jpg |   0    |    12     |
# | frame_0133.jpg |   1    |    12     |
# | frame_0134.jpg |   1    |    11     |
# | frame_0153.jpg |   0    |    12     |
# | frame_0135.jpg |   1    |    10     |
# | frame_0106.jpg |   0    |    10     |
