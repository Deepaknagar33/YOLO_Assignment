# %% [markdown]
# # YOLOv8 Dataset Preparation & Augmentation
#
# ## 📁 1. Directory Setup
# - Define input and output paths.
# - Create subdirectories:
#   - `images/` for image files.
#   - `labels/` for YOLO-format annotation files.
# - Split data into `train`, `valid`, and `test`.
#
# ## 🔁 2. Data Augmentation using Albumentations
# - Augmentation techniques used:
#   - `HorizontalFlip(p=0.5)`
#   - `RandomBrightnessContrast(p=0.3)`
#   - `Rotate(limit=15, p=0.2)`
#   - `MotionBlur(p=0.1)`
# - Bounding boxes are preserved using `bbox_params`.
#
# ## 📦 3. VOC to YOLO Format Conversion
# - Each bounding box from Pascal VOC is converted to YOLO format:
#   - `x_center = (xmin + xmax)/2`
#   - `y_center = (ymin + ymax)/2`
#   - `width = xmax - xmin`
#   - `height = ymax - ymin`
# - Normalized by image width and height.
#
# ## 📄 4. XML Annotation Parsing
# - Parses `.xml` files for bounding boxes and labels.
# - Filters only two classes:
#   - `space-empty` → class 0
#   - `space-occupied` → class 1
#
# ## ✍️ 5. Save YOLO Labels
# - Writes `.txt` file per image in the YOLO format:
#
# ## 🔁 6. Process Images
# For each image in `train`, `valid`, and `test`:
# 1. Parse and convert the annotation.
# 2. Save original image and its label.
# 3. Generate **2 augmented versions** using the defined pipeline.
# 4. Save augmented images and labels.
#
# ## ✅ 7. Final Result
# Each original image has:
# - 1 original + 2 augmented images.
# - Corresponding `.txt` YOLO label files saved in appropriate split folders.

# %%
import os
import glob
import cv2
import shutil
import xml.etree.ElementTree as ET
from pathlib import Path
from tqdm import tqdm
import albumentations as A

# Paths
INPUT_ROOT = "/home/user/YOLO_Assignment/Task_1/Dataset/pklot_raw"         
OUTPUT_ROOT = "/home/user/YOLO_Assignment/Task_1/Dataset/dataset_yolo"     
SPLITS = ['train', 'valid', 'test']

# Create output folders
for split in SPLITS:
    os.makedirs(f"{OUTPUT_ROOT}/{split}/images", exist_ok=True)
    os.makedirs(f"{OUTPUT_ROOT}/{split}/labels", exist_ok=True)

# Augmentation pipeline
augmenter = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.3),
    A.Rotate(limit=15, p=0.2),
    A.MotionBlur(p=0.1)
], bbox_params=A.BboxParams(format='yolo', label_fields=['class_labels']))

# VOC to YOLO box conversion
def convert_bbox_voc_to_yolo(size, box):
    dw = 1. / size[0]
    dh = 1. / size[1]
    x_center = (box[0] + box[2]) / 2.0
    y_center = (box[1] + box[3]) / 2.0
    width = box[2] - box[0]
    height = box[3] - box[1]
    return [x_center * dw, y_center * dh, width * dw, height * dh]

# Parse XML annotation
def parse_voc_xml(xml_path):
    tree = ET.parse(xml_path)
    root = tree.getroot()
    size = root.find('size')
    w = int(size.find('width').text)
    h = int(size.find('height').text)

    boxes, labels = [], []
    for obj in root.findall('object'):
        label = obj.find('name').text.strip().lower()
        if label not in ['space-empty', 'space-occupied']:
            continue
        class_id = 0 if label == 'space-empty' else 1
        xml_box = obj.find('bndbox')
        box = [int(xml_box.find('xmin').text), int(xml_box.find('ymin').text),
               int(xml_box.find('xmax').text), int(xml_box.find('ymax').text)]
        yolo_box = convert_bbox_voc_to_yolo((w, h), box)
        boxes.append(yolo_box)
        labels.append(class_id)
    return boxes, labels, w, h

# Save YOLO labels
def save_yolo_label(path, bboxes, labels):
    with open(path, 'w') as f:
        for label, box in zip(labels, bboxes):
            f.write(f"{label} {' '.join(map(str, box))}\n")

# Main loop over train/val/test
for split in SPLITS:
    img_dir = os.path.join(INPUT_ROOT, split)
    all_images = sorted(glob.glob(os.path.join(img_dir, "*.jpg")))

    for img_path in tqdm(all_images, desc=f"Processing {split}"):
        filename = os.path.basename(img_path)
        xml_path = Path(img_path).with_suffix('.xml')

        if not os.path.exists(xml_path):
            print(f"XML not found for: {filename}")
            continue

        bboxes, labels, w, h = parse_voc_xml(xml_path)
        if not bboxes:
            print(f"No relevant labels in: {filename}")
            continue

        image = cv2.imread(img_path)

        # Save original image and label
        out_img_path = f"{OUTPUT_ROOT}/{split}/images/{filename}"
        out_lbl_path = f"{OUTPUT_ROOT}/{split}/labels/{filename.replace('.jpg', '.txt')}"
        shutil.copy(img_path, out_img_path)
        save_yolo_label(out_lbl_path, bboxes, labels)

        # Augmentations (2 copies per image)
        for i in range(2):
            aug = augmenter(image=image, bboxes=bboxes, class_labels=labels)
            aug_img = aug['image']
            aug_boxes = aug['bboxes']
            aug_labels = aug['class_labels']
            aug_fname = filename.replace('.jpg', f'_aug{i}.jpg')

            cv2.imwrite(f"{OUTPUT_ROOT}/{split}/images/{aug_fname}", aug_img)
            save_yolo_label(f"{OUTPUT_ROOT}/{split}/labels/{aug_fname.replace('.jpg', '.txt')}", aug_boxes, aug_labels)

print("\n Preprocessing and augmentation (original + augmented) complete.")
# Out:
# Processing train:  57%|██████████████████████████████████████████████████████▎                                         | 4914/8691 [01:50<00:06, 540.42it/s]
# No relevant labels in: 2012-12-28_08_25_03_jpg.rf.4609384819dfcc8d0f87adc656473ba4.jpg
# No relevant labels in: 2012-12-28_08_35_03_jpg.rf.e47e6a25ba8efb94752f072f74150491.jpg
# No relevant labels in: 2012-12-28_08_40_03_jpg.rf.d776f29ae49ec76b2209984c1a2814a8.jpg
# No relevant labels in: 2012-12-28_08_45_03_jpg.rf.af314dbb9225c1a0692dadf1789ce59a.jpg
# No relevant labels in: 2012-12-28_08_55_04_jpg.rf.94465b25e539be587ba4cbc7fa8db70b.jpg
# No relevant labels in: 2012-12-28_09_00_04_jpg.rf.2fd6f55d88c4790c5b56a7b5bc55cb7e.jpg
# No relevant labels in: 2012-12-28_09_05_04_jpg.rf.021676ce6d340649a2989973f74eb758.jpg
# No relevant labels in: 2012-12-28_09_10_04_jpg.rf.14bf118d4f1e71dc7c9e3ad0b894f80b.jpg
# No relevant labels in: 2012-12-28_09_25_04_jpg.rf.9869a276ab1a3e4523db2d579f2f24bf.jpg
# No relevant labels in: 2012-12-28_09_30_04_jpg.rf.8d4b4153aa12bb362e6961e1a7a32e39.jpg
# No relevant labels in: 2012-12-28_09_50_05_jpg.rf.bf630b840b66acabc717d47b2229c08c.jpg
# No relevant labels in: 2012-12-28_10_00_05_jpg.rf.467f6888c0a012d642c426a2556a4f44.jpg
# No relevant labels in: 2012-12-28_10_10_05_jpg.rf.e1aad04f40762d3d96c28bdd537cb2e1.jpg
# No relevant labels in: 2012-12-28_10_15_05_jpg.rf.a6f132fc11843cf4f03b591356e3a432.jpg
# No relevant labels in: 2012-12-28_10_30_06_jpg.rf.50ddb31ff18663d38d5a1a874614bad0.jpg
# No relevant labels in: 2012-12-28_10_35_06_jpg.rf.f0209e39a76c710bc4475c6aa5d4d436.jpg
# No relevant labels in: 2012-12-28_10_40_06_jpg.rf.9989f3814cab50ea715a20bac7f58909.jpg
# No relevant labels in: 2012-12-28_10_55_06_jpg.rf.568f5b469dcb1ca60b2fbb9d75be85b4.jpg
# No relevant labels in: 2012-12-28_11_00_06_jpg.rf.8c146c048910929d7d963e882d1c0074.jpg
# No relevant labels in: 2012-12-28_11_05_06_jpg.rf.41de01849dae88b87b6c6fe8d66bb5ff.jpg
# No relevant labels in: 2012-12-28_11_10_06_jpg.rf.551d97fc30bed7236dd00d34c3f139e1.jpg
# No relevant labels in: 2012-12-28_11_20_07_jpg.rf.efe81aae073ea726b8d838b8a464548f.jpg
# No relevant labels in: 2012-12-28_11_25_07_jpg.rf.87d3455ac04103ff31d42916e64e7a5e.jpg
# No relevant labels in: 2012-12-28_11_30_07_jpg.rf.15540b38ccc1b6e79fdff08b67c834e9.jpg
# No relevant labels in: 2012-12-28_11_35_07_jpg.rf.e97e247ca724ae17e627946a5d99e7fb.jpg
# No relevant labels in: 2012-12-28_11_45_07_jpg.rf.7a3b5bae5888fe2eb45eacadd1f67237.jpg
# No relevant labels in: 2012-12-28_11_50_07_jpg.rf.db78e4c5a5fc88724ad321a9859b19df.jpg
# No relevant labels in: 2012-12-28_11_55_07_jpg.rf.547bdec50f442114cfe8f12fe0557778.jpg
# No relevant labels in: 2012-12-28_12_10_08_jpg.rf.07dcba9c70cd69600a21d7b4a87ecfee.jpg
# No relevant labels in: 2012-12-28_12_15_08_jpg.rf.6f4621f24dacee1db3f5dd0a2dd4cecd.jpg
# No relevant labels in: 2012-12-28_12_20_08_jpg.rf.5724ffb51fe58cef1403ca1c7345d3d6.jpg
# No relevant labels in: 2012-12-28_12_25_08_jpg.rf.a2bd7f674ee07fc538ad6bee50acb928.jpg
# No relevant labels in: 2012-12-28_12_35_08_jpg.rf.02da41499bcae8c26911f8211be5b10f.jpg
# No relevant labels in: 2012-12-28_12_40_08_jpg.rf.982353efff8ac8d58b93044b5c5c639c.jpg
# No relevant labels in: 2012-12-28_12_50_08_jpg.rf.dd763a99f4368305d64aa437dc573992.jpg
# No relevant labels in: 2012-12-28_13_00_09_jpg.rf.1ff2ba1ede768e8f0edf1140a218f514.jpg
# No relevant labels in: 2012-12-28_13_10_09_jpg.rf.3b06fe38c482c7e64aede6e59cd46463.jpg
# No relevant labels in: 2012-12-28_13_15_09_jpg.rf.8cf3b920fe8fe996c6b8fc204c0a2e1f.jpg
# No relevant labels in: 2012-12-28_13_20_09_jpg.rf.a3865c5911de68c67f5d075ab7f106c6.jpg
# No relevant labels in: 2012-12-28_13_25_09_jpg.rf.796c13970cce1524a4ed110bb199e3bc.jpg
# No relevant labels in: 2012-12-28_13_35_09_jpg.rf.5229f8352020784e324f7ef79dca741d.jpg
# No relevant labels in: 2012-12-28_13_40_09_jpg.rf.bdb9f386c3fe0997e381e6ebe0e23ea2.jpg
# No relevant labels in: 2012-12-28_13_45_09_jpg.rf.69bf9be863748d5ad9808e9a06daa0c2.jpg
# No relevant labels in: 2012-12-28_13_50_09_jpg.rf.ddcd72232974864d86bbb1c7fa865010.jpg
# No relevant labels in: 2012-12-28_14_00_10_jpg.rf.ec1143d705e9ee2dd6bee9d24bbe22cc.jpg
# No relevant labels in: 2012-12-28_14_05_10_jpg.rf.b5803fbbc3e74cc8574b52c88e103260.jpg
# No relevant labels in: 2012-12-28_14_20_10_jpg.rf.be39b286adfb269d1085ecb294506347.jpg
# No relevant labels in: 2012-12-28_14_30_10_jpg.rf.eb3229255b491626ba7f1d908eb4c27a.jpg
# No relevant labels in: 2012-12-28_14_35_10_jpg.rf.c81de9ad3caf6ccdccdc3a451c77ee08.jpg
# No relevant labels in: 2012-12-28_14_45_10_jpg.rf.9c5abd8912c123afa93d9ec414cd9cce.jpg
# No relevant labels in: 2012-12-28_14_50_10_jpg.rf.13b13316a944a6a41d1d13b90538a25b.jpg
# No relevant labels in: 2012-12-28_14_55_11_jpg.rf.cee699b9437ac0aa01aca616bf5aa9fc.jpg
# No relevant labels in: 2012-12-28_15_00_11_jpg.rf.cc814f9651c2f1bf2ac1440f6995bdf1.jpg
# No relevant labels in: 2012-12-28_15_05_11_jpg.rf.b0fa4c30749a620df1fbb66041e04da3.jpg
# No relevant labels in: 2012-12-28_15_10_11_jpg.rf.ed4ed16977377cbb29a5985deacb00b8.jpg
# No relevant labels in: 2012-12-28_15_15_11_jpg.rf.1bae3c77c9d12570586d8626c2598c32.jpg
# No relevant labels in: 2012-12-28_15_25_11_jpg.rf.ff691d1363b3c97a8f28b984b0668922.jpg
# No relevant labels in: 2012-12-28_15_30_11_jpg.rf.63390a83fe8a727ce6b9e3b778703837.jpg
# No relevant labels in: 2012-12-28_15_35_11_jpg.rf.82ad3c4e3e149606f01dbae8604781e8.jpg
# No relevant labels in: 2012-12-28_15_45_11_jpg.rf.6fd40e56dfe386695b3f16500595c84c.jpg
# No relevant labels in: 2012-12-28_15_50_11_jpg.rf.8af0b503c33614fe25f7bc4b851288c1.jpg
# No relevant labels in: 2012-12-28_15_55_11_jpg.rf.b3254293d53ee23df0d4740825125396.jpg
# No relevant labels in: 2012-12-28_16_00_12_jpg.rf.c1d786a41c5e403210f03f8803528120.jpg
# No relevant labels in: 2012-12-28_16_05_12_jpg.rf.1897b26f7898f3c9b2f44bb9db519cc7.jpg
# No relevant labels in: 2012-12-28_16_15_12_jpg.rf.686e12f151837d96eee5c752814531bc.jpg
# No relevant labels in: 2012-12-28_16_35_12_jpg.rf.cd63ee36445cf85c9d8dcd2ae4e1e602.jpg
# No relevant labels in: 2012-12-28_16_50_12_jpg.rf.c9aed4d63d02c1a74efa2943a9189d64.jpg
# No relevant labels in: 2012-12-28_16_55_13_jpg.rf.da0d570ecb6585caddf4447c7df2a7a3.jpg
# No relevant labels in: 2012-12-28_17_00_13_jpg.rf.bdaf72af26037880f51eb265105a8db0.jpg
# No relevant labels in: 2012-12-28_17_15_13_jpg.rf.46a1182e5a82029c76a03c760000d472.jpg
# No relevant labels in: 2012-12-28_17_20_13_jpg.rf.ad2e97a5d289d804b869e2b76ab13666.jpg
# No relevant labels in: 2012-12-28_17_25_13_jpg.rf.0e8894887719c1a8de9c1b8afb86a219.jpg
# No relevant labels in: 2012-12-28_17_30_13_jpg.rf.6216b50e41f4c3e86622e1c8981eea81.jpg
# No relevant labels in: 2012-12-28_17_35_13_jpg.rf.ca44d6fae73c77b6814dd9dd420140b2.jpg
# No relevant labels in: 2012-12-28_17_40_13_jpg.rf.62fcd3be409ff6532033ea73b85de7b3.jpg
# No relevant labels in: 2012-12-28_17_50_13_jpg.rf.7e5e5c2161ef9b6c486d1592af0650ad.jpg
# No relevant labels in: 2012-12-28_18_00_14_jpg.rf.430adf2ff7a9ebfcadfea4792c161369.jpg
# No relevant labels in: 2012-12-28_18_05_14_jpg.rf.59fbceb08413eac84724558e6d624274.jpg
# No relevant labels in: 2012-12-28_18_10_14_jpg.rf.69a288fea50fb13b2f7f86fd7004c3f2.jpg
# No relevant labels in: 2012-12-28_18_25_14_jpg.rf.5f70c5cefc3c32670bd046ae191f1249.jpg
# No relevant labels in: 2012-12-28_18_30_14_jpg.rf.d2cd7aa6800c9725f5c81aa10e49a586.jpg
# No relevant labels in: 2012-12-28_18_35_14_jpg.rf.1ce1a4d7d2212e5a920c980c5c4f95a7.jpg
# No relevant labels in: 2012-12-28_18_40_14_jpg.rf.db35d2b6291d86ac2ebd5ee846bc3200.jpg
# No relevant labels in: 2012-12-28_18_45_15_jpg.rf.de21cb9a8d18b3041eaaa86fe5bc3875.jpg
# No relevant labels in: 2012-12-28_18_50_15_jpg.rf.738b51a9d2762c4bfff12cd83ac54052.jpg
# No relevant labels in: 2012-12-28_18_55_15_jpg.rf.1bb5fb27cbea5f88dbc28dd8bf58b69e.jpg
# No relevant labels in: 2012-12-28_19_10_15_jpg.rf.627831452293996d94b84536d51c9e23.jpg
# No relevant labels in: 2012-12-28_19_20_15_jpg.rf.1a9bdfdfd9d3cdb7114b1e9ba8f57230.jpg
# No relevant labels in: 2012-12-28_19_30_15_jpg.rf.683349cb490429b81e8075c6ef1956ce.jpg
# No relevant labels in: 2012-12-28_19_35_16_jpg.rf.5b76ff8e991d225c5f04b5e5457437f3.jpg
# No relevant labels in: 2012-12-28_19_40_16_jpg.rf.0e27e6934982eb2f35191d1d1294e033.jpg
# No relevant labels in: 2012-12-28_19_55_16_jpg.rf.3feef676020242016f6daa913188f571.jpg
# No relevant labels in: 2012-12-28_20_00_16_jpg.rf.b3c31e7b097e8a353245d8f1e2eacba7.jpg
# No relevant labels in: 2012-12-28_20_10_16_jpg.rf.2b1e565c206bf6309af08a43924d7d12.jpg
# No relevant labels in: 2012-12-28_20_20_16_jpg.rf.dc59e6e3036fa636e1ebe7129f5ccacd.jpg
# No relevant labels in: 2012-12-28_20_25_17_jpg.rf.9e28439a548328de31d75f22dfc4fbf7.jpg
# No relevant labels in: 2012-12-28_20_30_17_jpg.rf.73159fe3304139f261dbccbbdd67bd6c.jpg
# No relevant labels in: 2012-12-28_20_35_17_jpg.rf.c2893818ebbdd780fd78590586d87dd8.jpg
# No relevant labels in: 2012-12-28_20_40_17_jpg.rf.68caf4686b408b23379f000750b7188e.jpg
# No relevant labels in: 2012-12-28_20_45_17_jpg.rf.d73caa52a62cb658f4f6f6a0584c108c.jpg
# No relevant labels in: 2012-12-28_21_05_17_jpg.rf.5239de24b07987b62f5dfd9faa4ec3db.jpg
# No relevant labels in: 2012-12-29_09_30_05_jpg.rf.70ebeb27b3de20ece4ca98eca4dac483.jpg
# No relevant labels in: 2012-12-29_09_45_05_jpg.rf.1420c9e1e78a82b9d58eb6ca976a446f.jpg
# No relevant labels in: 2012-12-29_09_50_05_jpg.rf.5a7364aad80d4ef27ad973356fece50c.jpg
# No relevant labels in: 2012-12-29_10_00_05_jpg.rf.84606e8fb3813ba01fbc083a0645bc18.jpg
# No relevant labels in: 2012-12-29_10_05_05_jpg.rf.d68a3c1545f591440c0d6ad305260895.jpg
# No relevant labels in: 2012-12-29_10_10_05_jpg.rf.b134e53d0fab8f2f9802ca8ef554f25a.jpg
# No relevant labels in: 2012-12-29_10_15_05_jpg.rf.5ccbc2a4bd2a97ea297288dc58dd4aad.jpg
# No relevant labels in: 2012-12-29_10_20_05_jpg.rf.8fc1955b7489e1825c944a175c5550f6.jpg
# No relevant labels in: 2012-12-29_10_25_05_jpg.rf.6dd036bbbb76035734bc78d5feec47ba.jpg
# No relevant labels in: 2012-12-29_10_30_05_jpg.rf.4743a009c253fe1c07f1ac822dec47a1.jpg
# No relevant labels in: 2012-12-29_10_35_06_jpg.rf.4b4c384c7d77f4157050c593fda9f4f7.jpg
# No relevant labels in: 2012-12-29_10_40_06_jpg.rf.497a87036e8ef6a5fbcb3cb348f31033.jpg
# No relevant labels in: 2012-12-29_10_45_06_jpg.rf.c2e1da317371c03a0fc9cbac7605d14f.jpg
# No relevant labels in: 2012-12-29_10_50_06_jpg.rf.b066c29059aa840b78b394cca60f0363.jpg
# No relevant labels in: 2012-12-29_10_55_06_jpg.rf.d41a889b53b5cc3806c2f97def984365.jpg
# No relevant labels in: 2012-12-29_11_00_06_jpg.rf.489d8f1bbc7a9e6c6d74897709ebae38.jpg
# No relevant labels in: 2012-12-29_11_10_33_jpg.rf.960c18df6db1ea4569d4e6a74b7c1d0a.jpg
# No relevant labels in: 2012-12-29_11_15_33_jpg.rf.4c347168d1aca0b3e9d937b4e7ab61b6.jpg
# No relevant labels in: 2012-12-29_11_20_33_jpg.rf.4fc6d8d5315b0cf2e2643dbdc530d2dd.jpg
# No relevant labels in: 2012-12-29_11_30_34_jpg.rf.23841c20d0824acbad2460e6e8ef1b41.jpg
# No relevant labels in: 2012-12-29_11_45_34_jpg.rf.7f9518ff03050b34090cd0e3a1ba1639.jpg
# No relevant labels in: 2012-12-29_11_50_34_jpg.rf.7a15dad67d0332ef388aaf1e58f19209.jpg
# No relevant labels in: 2012-12-29_11_55_34_jpg.rf.fc05a4f4b30cfc3c6769331f0ef27d20.jpg
# No relevant labels in: 2012-12-29_12_00_34_jpg.rf.c86c6211e8d86870d9b9b8816e441854.jpg
# No relevant labels in: 2012-12-29_12_05_34_jpg.rf.f7bd50ad2a4b18531ad23080ef955027.jpg
# No relevant labels in: 2012-12-29_12_15_34_jpg.rf.7ff18108ca6d7297ed8d4836518e3ce2.jpg
# No relevant labels in: 2012-12-29_12_30_35_jpg.rf.7fa8ed0c5d34af1f6b27f5284ed29375.jpg
# No relevant labels in: 2012-12-29_12_45_35_jpg.rf.67601f911bea52c98ba3cdfd733f135a.jpg
# No relevant labels in: 2012-12-29_12_50_35_jpg.rf.ada060cdbacde7f40d33ff5b804be5d4.jpg
# No relevant labels in: 2012-12-29_13_05_36_jpg.rf.afe1d495ad7aa46d97487ae5d7a2a0dc.jpg
# No relevant labels in: 2012-12-29_13_10_36_jpg.rf.e23cef6b0f173388d8d1ef240692edd7.jpg
# No relevant labels in: 2012-12-29_13_15_36_jpg.rf.83d2d3d99f870faa8541585c16c1a47d.jpg
# No relevant labels in: 2012-12-29_13_25_36_jpg.rf.d8f24b21c16ade68516704a182825d20.jpg
# No relevant labels in: 2012-12-29_13_35_36_jpg.rf.11e5137995e92826d1edbc56dceab571.jpg
# No relevant labels in: 2012-12-29_13_40_36_jpg.rf.f8b65fbe7b2a15f9aecba830a8b21d4e.jpg
# No relevant labels in: 2012-12-29_13_55_37_jpg.rf.0514c496d054bea1e2e21652914d1832.jpg
# No relevant labels in: 2012-12-29_14_00_37_jpg.rf.9cb17eb2bc24ad9dbbd9078ea916e52a.jpg
# No relevant labels in: 2012-12-29_14_10_37_jpg.rf.3c4b15139f40a7d4b4264eea01e53d83.jpg
# No relevant labels in: 2012-12-29_14_30_37_jpg.rf.9f57d157d7f901c2f401a95ddf102afa.jpg
# No relevant labels in: 2012-12-29_14_40_37_jpg.rf.98ee0fc55adb69d326bef25e08edd323.jpg
# No relevant labels in: 2012-12-29_14_45_37_jpg.rf.63b4d07001e6ba8a8c571b146cf21375.jpg
# No relevant labels in: 2012-12-29_14_50_38_jpg.rf.57be790c2881320b4440dc91b256889d.jpg
# No relevant labels in: 2012-12-29_14_55_38_jpg.rf.f27c556f65c6fa5f431543e4c630da29.jpg
# No relevant labels in: 2012-12-29_15_00_38_jpg.rf.4beea24f70235517422cd9d026fe02c0.jpg
# No relevant labels in: 2012-12-29_15_05_38_jpg.rf.845c1ab6e74ffaa9ecca940f32948062.jpg
# No relevant labels in: 2012-12-29_15_10_38_jpg.rf.3342cd535c460e7b52611300c90c7d41.jpg
# No relevant labels in: 2012-12-29_15_15_38_jpg.rf.99352de53c0abd339c1c22e8aa449a4a.jpg
# No relevant labels in: 2012-12-29_15_20_38_jpg.rf.d740cdeacb373ee96ccd1e4115afccac.jpg
# No relevant labels in: 2012-12-29_15_25_38_jpg.rf.1ba54cc8ea97d347cd6c425997a74009.jpg
# No relevant labels in: 2012-12-29_15_30_38_jpg.rf.ae663cbce71ebda79d2e858a6f1eb344.jpg
# No relevant labels in: 2012-12-29_15_35_38_jpg.rf.6a8fc03301cbd2d8ba074aa0608b14c1.jpg
# No relevant labels in: 2012-12-29_15_45_39_jpg.rf.716fddd6fdac5e4f63f42181fc0dc628.jpg
# No relevant labels in: 2012-12-29_15_50_39_jpg.rf.4db088ee17f9920318617b0a66d92d2c.jpg
# No relevant labels in: 2012-12-29_15_55_39_jpg.rf.ec38072882eecc7f7dc9f80abe696786.jpg
# No relevant labels in: 2012-12-29_16_00_39_jpg.rf.2f85a73e4a48498c08258f40d7c068b1.jpg
# No relevant labels in: 2012-12-29_16_05_39_jpg.rf.66d88c93fa692ce70e7f9ad22b22c17a.jpg
# No relevant labels in: 2012-12-29_16_15_39_jpg.rf.bc87d29fadab2da3cc5139721e0398f1.jpg
# No relevant labels in: 2012-12-29_16_20_39_jpg.rf.7cabbdf3d7de7c5c296c6c25a7605aa4.jpg
# No relevant labels in: 2012-12-29_16_35_40_jpg.rf.5905e226b0e70b181e53d4387330177d.jpg
# No relevant labels in: 2012-12-29_16_40_40_jpg.rf.b2c9ebd56517b655feef5fdd8a6b73ee.jpg
# No relevant labels in: 2012-12-29_16_50_40_jpg.rf.f69b09eecf1fb69fb2bd953578897394.jpg
# No relevant labels in: 2012-12-29_16_55_40_jpg.rf.7056398a4755a6108d57a0c23a53d33a.jpg
# No relevant labels in: 2012-12-29_17_00_40_jpg.rf.e3feda2cfd850bac3b09dfe70c75578b.jpg
# No relevant labels in: 2012-12-29_17_05_40_jpg.rf.7d50f4a8d680a9250a45ee94430fbfe6.jpg
# No relevant labels in: 2012-12-29_17_10_40_jpg.rf.8ad16053a545681d2c90496a1910a3fd.jpg
# No relevant labels in: 2012-12-29_17_15_41_jpg.rf.85be93a7fa4298a227634077c0ffbb06.jpg
# No relevant labels in: 2012-12-29_17_20_41_jpg.rf.49cbac6561cc1be08a2a1f0ee9f4e908.jpg
# No relevant labels in: 2012-12-29_17_25_41_jpg.rf.e5f11cd6ab342e1929051560c589cfd4.jpg
# No relevant labels in: 2012-12-29_17_30_41_jpg.rf.08f2028c5045ae286fc29ae0cdae893f.jpg
# No relevant labels in: 2012-12-29_17_35_41_jpg.rf.c68574b57aedd9876d0b255caa622b8a.jpg
# No relevant labels in: 2012-12-29_17_45_41_jpg.rf.ccb3879d5170bdd66d73d6c584d33557.jpg
# No relevant labels in: 2012-12-29_17_50_41_jpg.rf.7ab7495163d6734c072f70766fc3a005.jpg
# No relevant labels in: 2012-12-29_18_25_42_jpg.rf.550fe8d1d12c07bd874b0456221f444b.jpg
# No relevant labels in: 2012-12-29_18_30_42_jpg.rf.e9c0d5d3b23a06647c85eac831ad1492.jpg
# No relevant labels in: 2012-12-29_18_35_42_jpg.rf.8facd5121b93cc6eb17480855ca74da8.jpg
# No relevant labels in: 2012-12-29_18_40_42_jpg.rf.df8c47d4bf1a570eb1adb59b78271afd.jpg
# No relevant labels in: 2012-12-29_18_45_42_jpg.rf.95965d655ca01f68b0ed9751f3d2aaa1.jpg
# No relevant labels in: 2012-12-29_18_50_42_jpg.rf.7fdb2d0e610ccd019c24d8114430ea57.jpg
# No relevant labels in: 2012-12-29_19_00_43_jpg.rf.3317d4f5f4a8e6937f808e8c6e78640e.jpg
# No relevant labels in: 2012-12-29_19_05_43_jpg.rf.fd3dd5b837dc27fb1cb3b87c71de61ab.jpg
# No relevant labels in: 2012-12-29_19_10_43_jpg.rf.fd48a96b6b127d500c9f98d5d2d43437.jpg
# No relevant labels in: 2012-12-29_19_15_43_jpg.rf.383848c83d2bfff68f86b0b0fe13c0e4.jpg
# No relevant labels in: 2012-12-29_19_20_43_jpg.rf.a138396defd9c4eef4fbfdc284a690af.jpg
# No relevant labels in: 2012-12-29_19_25_43_jpg.rf.65b6821b8c217c5e7f2ffdf696976314.jpg
# No relevant labels in: 2012-12-29_19_30_43_jpg.rf.4c5b088c803e8539f01e571fc74837da.jpg
# No relevant labels in: 2012-12-29_19_35_43_jpg.rf.22c4ba9efe032832c08a24965f758fdd.jpg
# No relevant labels in: 2012-12-29_19_40_43_jpg.rf.15a1d8fc6aff03d9d76fb113b0ffd71e.jpg
# No relevant labels in: 2012-12-29_19_45_43_jpg.rf.2c6635f111d0dfb03bdb9b4b953c1947.jpg
# Processing train: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 8691/8691 [03:11<00:00, 45.40it/s]
# Processing valid:  57%|██████████████████████████████████████████████████████▍                                         | 1409/2483 [00:30<00:05, 211.45it/s]
# No relevant labels in: 2012-12-28_08_30_03_jpg.rf.faea416c45c03741928a880f0174d90b.jpg
# No relevant labels in: 2012-12-28_08_50_04_jpg.rf.4e44291287ce7e11a9042466b7e39312.jpg
# No relevant labels in: 2012-12-28_09_15_04_jpg.rf.e1e4408c8e98ae094d9de078a9b967e1.jpg
# No relevant labels in: 2012-12-28_09_20_04_jpg.rf.7c727ee843d6c51c86682508f0b03995.jpg
# No relevant labels in: 2012-12-28_09_35_05_jpg.rf.e41c367fb1336bcd17a70208a555cef5.jpg
# No relevant labels in: 2012-12-28_09_40_05_jpg.rf.32d4775a6a7e16eb03796a6d98b0c41a.jpg
# No relevant labels in: 2012-12-28_09_45_05_jpg.rf.5280d465adc688216b1f714ed02fce43.jpg
# No relevant labels in: 2012-12-28_09_55_05_jpg.rf.b5d1e52974abf76359a3fc4b63e80438.jpg
# No relevant labels in: 2012-12-28_10_05_05_jpg.rf.da388211fadfaa49717ee83866172d8b.jpg
# No relevant labels in: 2012-12-28_10_20_05_jpg.rf.41a62fe04012a2341b1add8cc2cb81d0.jpg
# No relevant labels in: 2012-12-28_10_25_06_jpg.rf.6010fafc10e293b4226e98c530ca7005.jpg
# No relevant labels in: 2012-12-28_10_45_06_jpg.rf.7a05853361233821df61d56f40bfddc2.jpg
# No relevant labels in: 2012-12-28_10_50_06_jpg.rf.9cf81ccac7cff57dd328ccd467025d5e.jpg
# No relevant labels in: 2012-12-28_11_15_07_jpg.rf.ed8c03696b97030fc56c63c9e94f64fe.jpg
# No relevant labels in: 2012-12-28_11_40_07_jpg.rf.0576dbc71addbc0935e233e4b734e3ac.jpg
# No relevant labels in: 2012-12-28_12_05_08_jpg.rf.7a622eb2343bd1f4a21cf76d3bec07bb.jpg
# No relevant labels in: 2012-12-28_12_45_08_jpg.rf.c6fabd4ef852e5b51b95e99e69497d65.jpg
# No relevant labels in: 2012-12-28_12_55_08_jpg.rf.f06c5bb64fed34dce820c43653ebcf41.jpg
# No relevant labels in: 2012-12-28_13_30_09_jpg.rf.b668169d7e1705d734673b3cea85d82d.jpg
# No relevant labels in: 2012-12-28_13_55_09_jpg.rf.d304f9097311c5233fdc63954e02a5e2.jpg
# No relevant labels in: 2012-12-28_14_10_10_jpg.rf.70871f333f9fc37c21289530e30ee0e7.jpg
# No relevant labels in: 2012-12-28_14_15_10_jpg.rf.94ab9b7f776471ad3bba6d35d0aca8eb.jpg
# No relevant labels in: 2012-12-28_14_40_10_jpg.rf.28b7a6af1d56546bd0767a28ec331ce3.jpg
# No relevant labels in: 2012-12-28_15_40_11_jpg.rf.d4afb8b1b7fe450d201ee73421e339fb.jpg
# No relevant labels in: 2012-12-28_16_20_12_jpg.rf.3b8364da0fea70b9d4b89dffd4a82591.jpg
# No relevant labels in: 2012-12-28_16_25_12_jpg.rf.b31396ef5f083bcfca67461870c68f47.jpg
# No relevant labels in: 2012-12-28_16_30_12_jpg.rf.519be8ae5f1d59efd42010d8622dc6f8.jpg
# No relevant labels in: 2012-12-28_16_40_12_jpg.rf.b4f5734371d894117c9d66e9e934c384.jpg
# No relevant labels in: 2012-12-28_17_10_13_jpg.rf.643c31e9b777a3cfbee8ff89a1d5fdff.jpg
# No relevant labels in: 2012-12-28_18_15_14_jpg.rf.8f7a90d06ce260b3097d8cb8876275af.jpg
# No relevant labels in: 2012-12-28_19_00_15_jpg.rf.4039afe02456c74f7a85dd179454ce85.jpg
# No relevant labels in: 2012-12-28_19_15_15_jpg.rf.6077cf5a245d9bcc86acc5ef1b6e318c.jpg
# No relevant labels in: 2012-12-28_19_25_15_jpg.rf.471a94d236e8a61c06f97f97302c8fa0.jpg
# No relevant labels in: 2012-12-28_19_45_16_jpg.rf.cfb1e9f155388b2c7013104125d11256.jpg
# No relevant labels in: 2012-12-28_20_05_16_jpg.rf.9019e407707de0f258af0f9860bab1ca.jpg
# No relevant labels in: 2012-12-28_20_15_16_jpg.rf.a226795d07c64040aa0b13f0246fe5d7.jpg
# No relevant labels in: 2012-12-28_21_00_17_jpg.rf.95dd9173d06de47888dd691673772ca9.jpg
# No relevant labels in: 2012-12-29_09_35_05_jpg.rf.9273a980d8f1ca70ddfac0b14fee2f8a.jpg
# No relevant labels in: 2012-12-29_09_40_05_jpg.rf.0c6a57cd412b1ad910bf3793a4eabcf1.jpg
# No relevant labels in: 2012-12-29_09_55_05_jpg.rf.c1d3e1b06330dcf56ba6c0279c53d8f7.jpg
# No relevant labels in: 2012-12-29_11_05_33_jpg.rf.aaef4fe173f88a03249f2eef8634af7a.jpg
# No relevant labels in: 2012-12-29_11_25_33_jpg.rf.41cffb3e3d67be2d8373a4144a78f242.jpg
# No relevant labels in: 2012-12-29_11_40_34_jpg.rf.cccc458f0dc4f1bbcd065de0260785a9.jpg
# No relevant labels in: 2012-12-29_12_10_34_jpg.rf.6ccf6f5d3e96cc7dfbc59ea3666fd5cf.jpg
# No relevant labels in: 2012-12-29_12_20_35_jpg.rf.67c8116cb12b711b4321a6b815797cf9.jpg
# No relevant labels in: 2012-12-29_12_35_35_jpg.rf.e0116bb151d697a931a618ecc2c8f280.jpg
# No relevant labels in: 2012-12-29_12_40_35_jpg.rf.f4eaf79dbcb74b5da8497429cbf64da4.jpg
# No relevant labels in: 2012-12-29_13_00_36_jpg.rf.78c740f1d45a36d2877bbac36bab4b09.jpg
# No relevant labels in: 2012-12-29_13_20_36_jpg.rf.2dd5d5d083bf5f2a8f529abfd1ecbda9.jpg
# No relevant labels in: 2012-12-29_13_30_36_jpg.rf.b888e17132545c8149627701fb169a5e.jpg
# No relevant labels in: 2012-12-29_13_45_36_jpg.rf.b41aef628c48daa947cd431dcc441f89.jpg
# No relevant labels in: 2012-12-29_13_50_36_jpg.rf.25c6ee213b0403a8c0358c8c611846c1.jpg
# No relevant labels in: 2012-12-29_14_05_37_jpg.rf.01adbeb2a3ec5bb875ec790747d57283.jpg
# No relevant labels in: 2012-12-29_14_20_37_jpg.rf.42296c74a6eb9b423c85d2be0f1c06e7.jpg
# No relevant labels in: 2012-12-29_15_40_39_jpg.rf.db4747d71d062bb33c734dde28be1b1e.jpg
# No relevant labels in: 2012-12-29_16_10_39_jpg.rf.d5fc6a7e2089608f0c61275595137c0e.jpg
# No relevant labels in: 2012-12-29_16_30_40_jpg.rf.64e4eee7a649cd3a0485e3a4f9f252ff.jpg
# No relevant labels in: 2012-12-29_16_45_40_jpg.rf.b0df7eb482ca0a7324cc61e7119048e9.jpg
# No relevant labels in: 2012-12-29_17_40_41_jpg.rf.878f6443e82266bbacdc52027fd688f6.jpg
# Processing valid: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 2483/2483 [00:53<00:00, 46.68it/s]
# Processing test:  56%|██████████████████████████████████████████████████████▋                                           | 693/1242 [00:15<00:04, 119.47it/s]
# No relevant labels in: 2012-12-28_08_20_03_jpg.rf.7f55510c997ad06a8d16c69f4060fa37.jpg
# No relevant labels in: 2012-12-28_12_00_08_jpg.rf.c2edf2542910f0cd38533d13a2a0dcb0.jpg
# No relevant labels in: 2012-12-28_12_30_08_jpg.rf.f9066176d0d2623c8b173eeac19b7449.jpg
# No relevant labels in: 2012-12-28_13_05_09_jpg.rf.d53c0ebe4631635447996f865a0a07cf.jpg
# No relevant labels in: 2012-12-28_14_25_10_jpg.rf.aae9046d70d6b3ba2972680d2bb11449.jpg
# No relevant labels in: 2012-12-28_15_20_11_jpg.rf.7b54d3725c28b20fd485268a409eb34f.jpg
# No relevant labels in: 2012-12-28_16_10_12_jpg.rf.853708f9d2dde298fd80f7b390e497cc.jpg
# No relevant labels in: 2012-12-28_16_45_12_jpg.rf.ee22286a5c59b63d459ffcb1e01a5122.jpg
# No relevant labels in: 2012-12-28_17_05_13_jpg.rf.a251776af3fc8dbac659e5476b7ff7b8.jpg
# No relevant labels in: 2012-12-28_17_45_13_jpg.rf.800ddd598aa93c431645e7160e3cec36.jpg
# No relevant labels in: 2012-12-28_17_55_14_jpg.rf.3175e24f3c40cde6d2ad98b08d0cc90f.jpg
# No relevant labels in: 2012-12-28_18_20_14_jpg.rf.f6f0b9e4815e60652cc35334f3b9a1af.jpg
# No relevant labels in: 2012-12-28_19_05_15_jpg.rf.d56a395393b58eff579c2fe25d996238.jpg
# No relevant labels in: 2012-12-28_19_50_16_jpg.rf.c871e23822e77bc702c01a50869ea071.jpg
# No relevant labels in: 2012-12-28_20_50_17_jpg.rf.e9626b66f0fa204468cbfe708ad04478.jpg
# No relevant labels in: 2012-12-28_20_55_17_jpg.rf.1a81f0183497279767e320876465c96d.jpg
# No relevant labels in: 2012-12-29_11_35_34_jpg.rf.816ade648c62121d084b19a9d4fdd10d.jpg
# No relevant labels in: 2012-12-29_12_25_35_jpg.rf.7c66293161f6ce75e4969444db268f0b.jpg
# No relevant labels in: 2012-12-29_12_55_35_jpg.rf.437ee7bab6abb8ab2111c266a729e721.jpg
# No relevant labels in: 2012-12-29_14_15_37_jpg.rf.1811039850b61cdce0fa0a26e69baaeb.jpg
# No relevant labels in: 2012-12-29_14_25_37_jpg.rf.78c096adafb7d1ecc2efcde98e684112.jpg
# No relevant labels in: 2012-12-29_14_35_37_jpg.rf.14f0a2ab5709c3b7609f1249b6f15375.jpg
# No relevant labels in: 2012-12-29_16_25_40_jpg.rf.c16ee16f15290619017537e62e6854cf.jpg
# No relevant labels in: 2012-12-29_17_55_41_jpg.rf.67a84a1843c2832ceb4bb82e59ed7f5b.jpg
# No relevant labels in: 2012-12-29_18_05_42_jpg.rf.85a789ddeda7b1c648ac2c9a57042475.jpg
# No relevant labels in: 2012-12-29_18_55_43_jpg.rf.02f8dc95fe0fb570a9ed8a2533c2262f.jpg
# Processing test: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 1242/1242 [00:26<00:00, 46.48it/s]
#  Preprocessing and augmentation (original + augmented) complete.

# %% [markdown]
# # 📂 YOLOv8 Parking Dataset Summary
#
# ## 🔗 Dataset Download Link
# You can download the full YOLOv8-compatible dataset (including images, labels, and `data.yaml`) from the following Google Drive link:
#
# **[Download Dataset from Google Drive](https://drive.google.com/drive/folders/13KoJEiEwVik8_quz2z4oE8DF1LfieQ3f?usp=sharing)**
# *(Make sure the link has proper sharing permissions)*
#
# ## 📊 Dataset Split Summary
# | Split       | Number of Samples |
# |-------------|-------------------|
# | Train       | 25,507            |
# | Validation  | 7,273             |
# | Test        | 3,649             |
# | **Total**   | **36,429**        |
#
# ## ✅ Contents
# - YOLOv8-compatible structure with `images/` and `labels/` folders.
# - Augmented versions of images are included.
# - `data.yaml` configured for 2 classes:
#   - `0`: `space-empty`
#   - `1`: `space-occupied`

# %% [markdown]
# # 📄 Generate `data.yaml` for YOLOv8
#
# ## 🗂 1. Dataset Root
# - Set the root directory where the YOLO-formatted dataset is saved.
#
# ## 📋 2. Define `data.yaml` Structure
# - YAML structure includes:
#   - `train`: Path to training images.
#   - `val`: Path to validation images.
#   - `test`: Path to test images.
#   - `nc`: Number of classes (2 in this case).
#   - `names`: Class names in the correct order for YOLO:
#     - `0` -> `space-empty`
#     - `1` -> `space-occupied`
#
# ## 💾 3. Save YAML File
# - The YAML dictionary is saved to `data.yaml` in the dataset root.
# - This file is required to train YOLOv8 using the Ultralytics framework.
#
# ## ✅ 4. Output
# - A `data.yaml` file is generated at:

# %%
import yaml
from pathlib import Path

# Define dataset root path
dataset_root = Path("/home/user/YOLO_Assignment/Task_1/Dataset/dataset_yolo")

# Define YAML content
data = {
    'train': str(dataset_root / 'train' / 'images'),
    'val': str(dataset_root / 'valid' / 'images'),
    'test': str(dataset_root / 'test' / 'images'),
    'nc': 2,
    'names': ['space-empty', 'space-occupied']
}

# Save YAML
yaml_path = dataset_root / "data.yaml"
with open(yaml_path, 'w') as f:
    yaml.dump(data, f)

print(f" data.yaml generated at: {yaml_path}")
# Out:
#  data.yaml generated at: /home/user/YOLO_Assignment/Task_1/Dataset/dataset_yolo/data.yaml
